# %%
from gsn import *
from conceptnet import *
from imagenet import *

# %%
# get gsn statistics of word counts
yearly_abs_counts, yearly_percent_counts, word2idx = get_word_counts(start_year=1800, end_year=2000, min_total_count=20000)
# Out:
# 100%|██████████| 99/99 [22:30<00:00, 13.65s/it]

# %%
gsn_vocab = word2idx.keys()
word2cnp_counts, word2idx, weighted_co_occurrences = get_cnp_stats(gsn_vocab)
# Out:
# 3408it [54:35,  1.04it/s]

# %%
# get mappings between ImageNet index, WordNetID (wnid) and words
image_paths, wnids = get_img_paths()
wnid2img_path_idx = get_wnid2img_path_idx(image_paths)
word2wnids = get_word2wnids(wnids)
word2img_idx = get_word2img_idx(word2wnids, wnid2img_path_idx)
# Out:
# 100%|██████████| 21841/21841 [12:16<00:00, 29.67it/s]

# %%
import pickle
# get words with sufficient ontological and visual representations
min_cnp_edges = 10
min_img_num = 100

cnp_word2idx = pickle.load(open('/h/19/jadeleiyu/frame_extension/data/cnp/word2cnp_idx.p', 'rb'))
word2cnp_counts = pickle.load(open('/h/19/jadeleiyu/frame_extension/data/cnp/word2cnp_counts.p', 'rb'))
word2img_idx = pickle.load(open('/h/19/jadeleiyu/frame_extension/data/img/imagenet_word2img_idx.p','rb'))
cnp_vocab = set(cnp_word2idx.keys())
img_vocab = set(word2img_idx.keys())

cnp_img_common_vocab = set([word for word in cnp_vocab if word in img_vocab
                            and word2cnp_counts[word] >= min_cnp_edges
                            and len(word2img_idx[word]) >= min_img_num])

# %%
# get words with sufficient GSN occurrences

word2gsn_idx = pickle.load(open('/h/19/jadeleiyu/frame_extension/data/gsn/word2idx.p', 'rb'))
gsn_yearly_abs_counts = pickle.load(open('/h/19/jadeleiyu/frame_extension/data/gsn/yearly_abs_counts.p', 'rb'))
gsn_vocab = set(word2gsn_idx.keys())
gsn_word2total_count_by_pos = pickle.load(open('/h/19/jadeleiyu/frame_extension/data/gsn/word2total_count.p', 'rb'))


freq_threshold = 100000
candidate_support_nouns = set([word for word in cnp_img_common_vocab
                           if sum(gsn_word2total_count_by_pos[word]) >= freq_threshold
                           and word in gsn_vocab
                           ])

# %%
len(candidate_support_nouns)
# Out:
# 4135

# %%
# choose candidate verbs with sufficient frequency in GSN
min_verb_freq = 60000
candidate_verbs = [word for word in word2gsn_idx.keys() if
                   gsn_word2total_count_by_pos[word][1] >= min_verb_freq]

# %%
len(candidate_verbs)
# Out:
# 5660

# %%
# extract v-r-n frame usages from GSN
rel_types = {'nsubj', 'dobj', 'iobj', 'pobj'}
preps = {'in', 'by', 'to', 'with', 'on', 'from', 'for', 'at', 'as', 'like', 'of', 'into', 'about', 'under'}
frame_df = get_frame_data(candidate_support_nouns, candidate_verbs, rel_types, preps)
frame_df.to_csv('/h/19/jadeleiyu/frame_extension/data/gsn/gsn_frame_df.csv', index=False)

# %%
import pandas as pd
frame_df = pd.read_csv('/h/19/jadeleiyu/frame_extension/data/gsn/gsn_frame_df.csv')
# aggregate frame usages with the same (noun, verb, relation) triples
agg_func = {}
for decade in range(1800, 2010, 10):
    agg_func['count in {}s'.format(decade)] = sum
grouped_frame_df = frame_df.groupby(['verb', 'relation', 'noun']).agg(agg_func).reset_index()

# %%
# choose frame usages with sufficient frequencies
grouped_frame_df['total count'] = grouped_frame_df.iloc[:, 3:].sum(axis=1)

# %%
total_freq_theta = 100
grouped_frame_df = grouped_frame_df[grouped_frame_df['total count'] >=100]
# Out:
#         verb relation       noun  count in 1800s  count in 1810s  \
# 1    abandon     dobj      abode               1               3
# 4    abandon     dobj     action               0               0
# 8    abandon     dobj   aircraft               0               0
# 17   abandon     dobj     animal               0               0
# 19   abandon     dobj  apartment               0               0
# ..       ...      ...        ...             ...             ...
# 334  abandon     dobj  framework               0               0
# 335  abandon     dobj     friend              56              62
# 337  abandon     dobj      fruit               0               1
# 338  abandon     dobj  furniture               0               0
# 339  abandon     dobj       game               0               0
#
#      count in 1820s  count in 1830s  count in 1840s  count in 1850s  \
# 1                 7               8              11              26
# 4                 6               0               1               9
# 8                 0               0               0               0
# 17                2               1              10              16
# 19                0               0               0               0
# ..              ...             ...             ...             ...
# 334               0               0               0               0
# 335             100              92             112             138
# 337               2               0               1               6
# 338               0               0               0               0
# 339               0               2               8              17
#
#      count in 1860s  ...  count in 1920s  count in 1930s  count in 1940s  \
# 1                17  ...               3               3               1
# 4                15  ...              25              30              26
# 8                 0  ...               0               3              47
# 17                5  ...               6               9               3
# 19                0  ...               7               3               2
# ..              ...  ...             ...             ...             ...
# 334               0  ...               2               0               4
# 335              98  ...              92              88              67
# 337               7  ...              12              34              24
# 338               0  ...               9              19               8
# 339              14  ...              52              27              21
#
#      count in 1950s  count in 1960s  count in 1970s  count in 1980s  \
# 1                13               7              11               9
# 4                67              73             147             135
# 8                48              85              56              93
# 17               14              17              23              24
# 19                3               7               4               6
# ..              ...             ...             ...             ...
# 334              15              39              44              79
# 335              79             190             174             199
# 337              36              80              58              56
# 338               6               6               1              11
# 339              33              71              69              86
#
#      count in 1990s  count in 2000s  total count
# 1                 6              37        239.0
# 4               175             229       1062.0
# 8                80             195        607.0
# 17               44             138        411.0
# 19               16              48        105.0
# ..              ...             ...          ...
# 334             167             171        529.0
# 335             308             819       3294.0
# 337              45             102        561.0
# 338               8              14        118.0
# 339             112             295       1001.0
#
# [100 rows x 25 columns]

# %%
for i in range(21):
    decade = 1800 + i*10
    grouped_frame_df['total count up to {}s'.format(decade)] = grouped_frame_df.iloc[:, 3:4+i].sum(axis=1)

# %%
grouped_frame_df.to_csv('/h/19/jadeleiyu/frame_extension/data/gsn/vr_grouped_frame_df_100.csv', index=False)

# %%
# aggregate frame usages by their support nouns
agg_func = {'noun': lambda x: list(x)}
for decade in range(1800, 2010, 10):
    agg_func['count in {}s'.format(decade)] = lambda x: list(x)
    agg_func['total count up to {}s'.format(decade)] = lambda x: list(x)
    
grouped_frame_df = grouped_frame_df.groupby(['verb', 'relation']).agg(agg_func).reset_index()

# %%
len(grouped_frame_df['verb'])
# Out:
# 28168

# %%
# save the grouped data frame of frame usages
grouped_frame_df.to_csv('/h/19/jadeleiyu/frame_extension/data/gsn/vrn_grouped_frame_df.csv', index=False)

# %%
# get the counts for each support noun by decade in frame_df
# so that when computing historical conceptnet embeddings later, we weight each node by its frequency on every decade
# in this way we can effectively avoid the affect of OCR-like errors
# e.g. even if the word "car" is present in GSN at 1800s, its extremely low frequency will make it contribute very 
# few to the diachronic embeddings at 1800s

import pandas as pd
frame_df = pd.read_csv('/h/19/jadeleiyu/frame_extension/data/gsn/gsn_frame_df.csv')
agg_func = {}
for decade in range(1800, 2010, 10):
    agg_func['count in {}s'.format(decade)] = sum
noun_grouped_frame_df = frame_df.groupby(['noun']).agg(agg_func).reset_index()
noun_grouped_frame_df.to_csv('/h/19/jadeleiyu/frame_extension/data/gsn/noun_decade_counts_df.csv', index=False)
# Out:
#           noun  count in 1800s  count in 1810s  count in 1820s  \
# 0       abacus               1               7              14
# 1       abbess              34              47             113
# 2        abbey             780            1182            1606
# 3        abode             592            1106            2532
# 4   aboriginal               0               0               5
# ..         ...             ...             ...             ...
# 95     anomaly              27              49             185
# 96         ant             206             312             484
# 97  antecedent             184             200             441
# 98    antelope              20              46              72
# 99     antenna               5              13              69
#
#     count in 1830s  count in 1840s  count in 1850s  count in 1860s  \
# 0               18              43              74              78
# 1              200             181             209             156
# 2             1882            2468            3248            2801
# 3             4571            5523            6934            5229
# 4               26              32              36              26
# ..             ...             ...             ...             ...
# 95             349             381             675             701
# 96             492             451             934             770
# 97             635             710            1350            1489
# 98             157             255             621             349
# 99             220              90             211             487
#
#     count in 1870s  count in 1880s  ...  count in 1910s  count in 1920s  \
# 0               94             119  ...             220             106
# 1              175             228  ...             251             376
# 2             3933            5142  ...            3954            3321
# 3             5857            8517  ...            5793            4284
# 4               22              47  ...              37              41
# ..             ...             ...  ...             ...             ...
# 95             964            1348  ...            1704            1466
# 96            1403            3428  ...            3288            2928
# 97            2173            3044  ...            2502            1865
# 98             479             808  ...             693             620
# 99             492             610  ...            1325            1410
#
#     count in 1930s  count in 1940s  count in 1950s  count in 1960s  \
# 0              102              83             252             395
# 1              198             102             169             209
# 2             2539            1816            3131            4159
# 3             2814            2256            3174            5273
# 4               55              40             161             174
# ..             ...             ...             ...             ...
# 95            1296            1754            3076            7109
# 96            2171            2155            3012            4089
# 97            1429            1348            2645            4707
# 98             437             333             541             911
# 99            1985            3843            4315            5187
#
#     count in 1970s  count in 1980s  count in 1990s  count in 2000s
# 0              313             329             449             738
# 1              133             140             191            1448
# 2             3736            3473            4592           16910
# 3             4806            3847            4952           26054
# 4              258             201             290             517
# ..             ...             ...             ...             ...
# 95            9451           12493           17574           25802
# 96            3913            4300            6516           19163
# 97            5072            6989            9472           17104
# 98             856             806            1085            4176
# 99            4480            7442           10590           24926
#
# [100 rows x 22 columns]

# %%
# compute numpy array of decade counts for support nouns 
import pandas as pd
import numpy as np

noun_grouped_frame_df = pd.read_csv('/h/19/jadeleiyu/frame_extension/data/gsn/noun_decade_counts_df.csv')
support_nouns = list(noun_grouped_frame_df['noun'])
support_noun2idx = {support_nouns[i]:i for i in range(len(support_nouns))}

noun_decade_counts = np.zeros((21, len(support_nouns)))
for decade in range(1800, 2010, 10):
    decade_idx = int((decade - 1800) / 10)
    noun_decade_counts[decade_idx] = np.array(noun_grouped_frame_df['count in {}s'.format(decade)])

pickle.dump(noun_decade_counts.astype(int), open('/h/19/jadeleiyu/frame_extension/data/gsn/noun_decade_counts.p', 'wb'))
pickle.dump(support_noun2idx, open('/h/19/jadeleiyu/frame_extension/data/gsn/support_noun2idx.p', 'wb'))

# %%
# compute conceptnet historical representations for all words in cnp vocab
# later we will only make use of the embeddings of support nouns 
import pickle
from conceptnet import *

word2cnp_idx = pickle.load(open('/h/19/jadeleiyu/frame_extension/data/cnp/word2cnp_idx.p', 'rb'))
weighted_co_occurrences = pickle.load(open('/h/19/jadeleiyu/frame_extension/data/cnp/weighted_co_occurrences.p', 'rb'))
noun_decade_counts = pickle.load(open('/h/19/jadeleiyu/frame_extension/data/gsn/noun_decade_counts.p', 'rb'))
support_noun2idx = pickle.load(open('/h/19/jadeleiyu/frame_extension/data/gsn/support_noun2idx.p', 'rb'))

compute_cnp_hist_embeddings(support_noun2idx, word2cnp_idx, weighted_co_occurrences, noun_decade_counts)
# Out:
#  24%|██▍       | 5/21 [00:00<00:01, 10.49it/s]
# converting co-occurrence matrix of decade 1850 into PPMI matrix...
# /h/19/jadeleiyu/frame_extension/src/conceptnet.py:73: RuntimeWarning: divide by zero encountered in true_divide
#   ppmi = sparse.diags(1 / word_counts).dot(counts_csr)
# /h/19/jadeleiyu/frame_extension/src/conceptnet.py:77: RuntimeWarning: divide by zero encountered in true_divide
#   ppmi = ppmi.dot(sparse.diags(1 / smooth_context_freqs))
# performing SVD on PPMI matrix of decade 1850...
# 100%|██████████| 21/21 [00:26<00:00,  1.27s/it]

# %%
# compute imagenet representations for support nouns 
from imagenet import compute_visual_representations
import pickle
support_noun2idx = pickle.load(open('/h/19/jadeleiyu/frame_extension/data/gsn/support_noun2idx.p', 'rb'))
image_paths = pickle.load(open('/h/19/jadeleiyu/frame_extension/data/img/imagenet_image_paths.p', 'rb'))
word2img_idx = pickle.load(open('/h/19/jadeleiyu/frame_extension/data/img/imagenet_word2img_idx.p', 'rb'))

compute_visual_representations(support_noun2idx, image_paths, word2img_idx, img_sample_size=64)

# %%
import pandas as pd
grouped_frame_df = pd.read_csv('/h/19/jadeleiyu/frame_extension/data/gsn/vrn_grouped_frame_df.csv')

# %%
from gsn import learning_df_prep
learning_df_prep(grouped_frame_df, start_dec=1850, end_dec=2000, freq_theta=5)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 191it [00:00, 1909.05it/s]
# 350it [00:00, 1799.94it/s]
# 542it [00:00, 1834.08it/s]
# 770it [00:00, 1946.30it/s]
# 989it [00:00, 1999.35it/s]
# 1173it [00:00, 1946.00it/s]
# 1355it [00:00, 1887.77it/s]
# 1530it [00:00, 1689.93it/s]
# 1775it [00:00, 1862.47it/s]
# 1963it [00:01, 1464.81it/s]
# 2145it [00:01, 1552.39it/s]
# 2397it [00:01, 1753.82it/s]
# 2634it [00:01, 1894.54it/s]
# 2839it [00:01, 1734.96it/s]
# 3026it [00:01, 1770.54it/s]
# 3213it [00:01, 1787.98it/s]
# 3399it [00:01, 1722.27it/s]
# 3629it [00:01, 1860.20it/s]
# 3859it [00:02, 1972.24it/s]
# 4080it [00:02, 2037.32it/s]
# 4289it [00:02, 1954.57it/s]
# 4489it [00:02, 1881.92it/s]
# 4681it [00:02, 1868.99it/s]
# 4891it [00:02, 1923.69it/s]
# 5086it [00:02, 1806.51it/s]
# 5316it [00:02, 1929.78it/s]
# 5514it [00:02, 1895.72it/s]
# 5707it [00:03, 1881.34it/s]
# 5915it [00:03, 1933.82it/s]
# 6162it [00:03, 2067.89it/s]
# 6373it [00:03, 2025.71it/s]
# 6579it [00:03, 1966.34it/s]
# 6779it [00:03, 1811.79it/s]
# 6965it [00:03, 1712.99it/s]
# 7229it [00:03, 1913.55it/s]
# 7440it [00:03, 1968.41it/s]
# 7645it [00:04, 1956.02it/s]
# 7846it [00:04, 1713.41it/s]
# 8027it [00:04, 1701.01it/s]
# 8204it [00:04, 738.29it/s]
# 8383it [00:04, 895.85it/s]
# 8530it [00:05, 1007.89it/s]
# 8742it [00:05, 1195.99it/s]
# 8928it [00:05, 1338.04it/s]
# 9111it [00:05, 1451.65it/s]
# 9289it [00:05, 1534.59it/s]
# 9486it [00:05, 1641.78it/s]
df = pd.read_csv('/h/19/jadeleiyu/frame_extension/data/gsn/gsn_learning_df_{}s.csv'.format(decade))
    for index, row in learning_df.iterrows():
        established_nouns = eval(row['established nouns'])
        nn_next = eval(row['novel nouns next decade'])
        nn_future = eval(row['novel nouns all future'])
        if len(established_nouns) >= min_estab_num and len(nn_next) >= min_novel_num and len(nn_future) >= min_novel_num:
            valid_row_idx.append(index)
    learning_df = learning_df.iloc[valid_row_idx, :]
    learning_df.to_csv('/h/19/jadeleiyu/frame_extension/data/gsn/gsn_learning_df_{}s.csv'.format(decade), index=False)
# Out:
# 100%|██████████| 16/16 [02:11<00:00,  8.24s/it]

# %%
# get verb2idx and rel2idx
import pandas as pd
grouped_frame_df = pd.read_csv('/h/19/jadeleiyu/frame_extension/data/gsn/grouped_frame_df.csv')

# %%
grouped_frame_df
# Out:
#           verb        relation  \
# 0      abandon            dobj
# 1      abandon           nsubj
# 2      abandon    pobj_prep.as
# 3      abandon    pobj_prep.at
# 4      abandon    pobj_prep.by
# ...        ...             ...
# 28163     zone    pobj_prep.in
# 28164     zoom            dobj
# 28165     zoom           nsubj
# 28166     zoom  pobj_prep.into
# 28167     zoom    pobj_prep.on
#
#                                                     noun  \
# 0      ['abode', 'action', 'aircraft', 'animal', 'apa...
# 1      ['body', 'camp', 'child', 'church', 'city', 'c...
# 2                           ['baby', 'child', 'failure']
# 3                    ['birth', 'foot', 'point', 'stage']
# 4      ['authority', 'brother', 'child', 'church', 'c...
# ...                                                  ...
# 28163                                   ['area', 'city']
# 28164                                 ['lens', 'window']
# 28165                                         ['camera']
# 28166                                           ['area']
# 28167                                  ['area', 'image']
#
#                                           count in 1800s  \
# 0      [1, 0, 0, 0, 0, 0, 4, 0, 4, 2, 0, 13, 0, 0, 1,...
# 1      [0, 5, 3, 0, 3, 0, 0, 0, 0, 22, 0, 0, 0, 3, 2,...
# 2                                              [0, 0, 0]
# 3                                           [0, 0, 0, 0]
# 4      [0, 4, 2, 2, 0, 2, 0, 0, 11, 2, 3, 15, 1, 0, 1...
# ...                                                  ...
# 28163                                             [0, 0]
# 28164                                             [0, 0]
# 28165                                                [0]
# 28166                                                [0]
# 28167                                             [0, 0]
#
#                                  total count up to 1800s  \
# 0      [1, 0, 0, 0, 0, 0, 4, 0, 4, 2, 0, 13, 0, 0, 1,...
# 1      [0, 5, 3, 0, 3, 0, 0, 0, 0, 22, 0, 0, 0, 3, 2,...
# 2                                              [0, 0, 0]
# 3                                           [0, 0, 0, 0]
# 4      [0, 4, 2, 2, 0, 2, 0, 0, 11, 2, 3, 15, 1, 0, 1...
# ...                                                  ...
# 28163                                             [0, 0]
# 28164                                             [0, 0]
# 28165                                                [0]
# 28166                                                [0]
# 28167                                             [0, 0]
#
#                                           count in 1810s  \
# 0      [3, 0, 0, 0, 0, 0, 1, 1, 7, 0, 0, 16, 12, 0, 1...
# 1      [4, 2, 7, 3, 1, 0, 0, 0, 1, 74, 0, 0, 2, 2, 2,...
# 2                                              [0, 0, 0]
# 3                                           [0, 0, 0, 0]
# 4      [0, 0, 1, 0, 0, 0, 1, 0, 10, 2, 2, 25, 0, 0, 1...
# ...                                                  ...
# 28163                                             [0, 0]
# 28164                                             [0, 0]
# 28165                                                [0]
# 28166                                                [0]
# 28167                                             [0, 0]
#
#                                  total count up to 1810s  \
# 0      [4, 0, 0, 0, 0, 0, 5, 1, 11, 2, 0, 29, 12, 0, ...
# 1      [4, 7, 10, 3, 4, 0, 0, 0, 1, 96, 0, 0, 2, 5, 4...
# 2                                              [0, 0, 0]
# 3                                           [0, 0, 0, 0]
# 4      [0, 4, 3, 2, 0, 2, 1, 0, 21, 4, 5, 40, 1, 0, 2...
# ...                                                  ...
# 28163                                             [0, 0]
# 28164                                             [0, 0]
# 28165                                                [0]
# 28166                                                [0]
# 28167                                             [0, 0]
#
#                                           count in 1820s  \
# 0      [7, 6, 0, 2, 0, 0, 7, 3, 12, 0, 1, 44, 4, 0, 0...
# 1      [3, 2, 5, 0, 0, 0, 0, 0, 10, 65, 0, 3, 5, 11, ...
# 2                                              [0, 0, 0]
# 3                                           [0, 0, 0, 0]
# 4      [0, 1, 8, 0, 0, 0, 0, 0, 12, 2, 11, 37, 9, 0, ...
# ...                                                  ...
# 28163                                             [0, 0]
# 28164                                             [0, 0]
# 28165                                                [0]
# 28166                                                [0]
# 28167                                             [0, 0]
#
#                                  total count up to 1820s  \
# 0      [11, 6, 0, 2, 0, 0, 12, 4, 23, 2, 1, 73, 16, 0...
# 1      [7, 9, 15, 3, 4, 0, 0, 0, 11, 161, 0, 3, 7, 16...
# 2                                              [0, 0, 0]
# 3                                           [0, 0, 0, 0]
# 4      [0, 5, 11, 2, 0, 2, 1, 0, 33, 6, 16, 77, 10, 0...
# ...                                                  ...
# 28163                                             [0, 0]
# 28164                                             [0, 0]
# 28165                                                [0]
# 28166                                                [0]
# 28167                                             [0, 0]
#
#                                           count in 1830s  ...  \
# 0      [8, 0, 0, 1, 0, 0, 4, 12, 8, 0, 0, 35, 10, 0, ...  ...
# 1      [10, 2, 3, 0, 0, 3, 5, 0, 22, 81, 0, 4, 2, 0, ...  ...
# 2                                              [0, 0, 1]  ...
# 3                                           [0, 0, 0, 0]  ...
# 4      [0, 6, 13, 0, 0, 3, 2, 0, 20, 1, 2, 34, 18, 0,...  ...
# ...                                                  ...  ...
# 28163                                             [0, 0]  ...
# 28164                                             [0, 0]  ...
# 28165                                                [0]  ...
# 28166                                                [0]  ...
# 28167                                             [0, 0]  ...
#
#                                           count in 1960s  \
# 0      [7, 73, 85, 17, 7, 175, 81, 54, 3, 38, 28, 53,...
# 1      [4, 16, 40, 14, 25, 5, 42, 10, 5, 67, 19, 68, ...
# 2                                             [7, 9, 16]
# 3                                       [12, 30, 26, 17]
# 4      [9, 2, 43, 15, 23, 5, 10, 7, 6, 11, 17, 106, 6...
# ...                                                  ...
# 28163                                           [27, 49]
# 28164                                            [10, 0]
# 28165                                                [0]
# 28166                                                [0]
# 28167                                             [0, 0]
#
#                                  total count up to 1960s  \
# 0      [176, 376, 183, 182, 31, 330, 455, 466, 116, 1...
# 1      [179, 157, 165, 157, 102, 56, 214, 91, 215, 12...
# 2                                           [12, 14, 90]
# 3                                     [50, 115, 129, 99]
# 4      [72, 65, 181, 131, 71, 150, 108, 86, 186, 70, ...
# ...                                                  ...
# 28163                                           [53, 73]
# 28164                                            [11, 0]
# 28165                                                [0]
# 28166                                                [0]
# 28167                                             [0, 0]
#
#                                           count in 1970s  \
# 0      [11, 147, 56, 23, 4, 255, 30, 50, 10, 33, 76, ...
# 1      [2, 21, 29, 9, 18, 6, 15, 4, 5, 50, 9, 70, 6, ...
# 2                                            [8, 19, 12]
# 3                                        [18, 3, 21, 19]
# 4      [19, 12, 50, 18, 40, 7, 16, 2, 3, 3, 10, 78, 1...
# ...                                                  ...
# 28163                                           [66, 30]
# 28164                                            [23, 0]
# 28165                                               [10]
# 28166                                                [0]
# 28167                                             [0, 0]
#
#                                  total count up to 1970s  \
# 0      [187, 523, 239, 205, 35, 585, 485, 516, 126, 1...
# 1      [181, 178, 194, 166, 120, 62, 229, 95, 220, 12...
# 2                                          [20, 33, 102]
# 3                                    [68, 118, 150, 118]
# 4      [91, 77, 231, 149, 111, 157, 124, 88, 189, 73,...
# ...                                                  ...
# 28163                                         [119, 103]
# 28164                                            [34, 0]
# 28165                                               [10]
# 28166                                                [0]
# 28167                                             [0, 0]
#
#                                           count in 1980s  \
# 0      [9, 135, 93, 24, 6, 284, 53, 59, 0, 27, 95, 36...
# 1      [1, 21, 36, 4, 15, 5, 6, 8, 3, 34, 16, 81, 13,...
# 2                                            [16, 45, 9]
# 3                                        [45, 5, 19, 14]
# 4      [11, 5, 46, 23, 11, 5, 18, 4, 1, 9, 6, 66, 162...
# ...                                                  ...
# 28163                                           [26, 16]
# 28164                                           [19, 12]
# 28165                                               [28]
# 28166                                                [1]
# 28167                                             [8, 6]
#
#                                  total count up to 1980s  \
# 0      [196, 658, 332, 229, 41, 869, 538, 575, 126, 2...
# 1      [182, 199, 230, 170, 135, 67, 235, 103, 223, 1...
# 2                                          [36, 78, 111]
# 3                                   [113, 123, 169, 132]
# 4      [102, 82, 277, 172, 122, 162, 142, 92, 190, 82...
# ...                                                  ...
# 28163                                         [145, 119]
# 28164                                           [53, 12]
# 28165                                               [38]
# 28166                                                [1]
# 28167                                             [8, 6]
#
#                                           count in 1990s  \
# 0      [6, 175, 80, 44, 16, 409, 47, 84, 2, 51, 265, ...
# 1      [11, 43, 33, 11, 23, 7, 16, 1, 0, 51, 10, 206,...
# 2                                          [38, 109, 19]
# 3                                       [85, 15, 16, 16]
# 4      [13, 10, 63, 39, 45, 6, 18, 16, 6, 14, 10, 111...
# ...                                                  ...
# 28163                                           [39, 30]
# 28164                                           [73, 46]
# 28165                                               [70]
# 28166                                               [16]
# 28167                                           [62, 21]
#
#                                  total count up to 1990s  \
# 0      [202, 833, 412, 273, 57, 1278, 585, 659, 128, ...
# 1      [193, 242, 263, 181, 158, 74, 251, 104, 223, 1...
# 2                                         [74, 187, 130]
# 3                                   [198, 138, 185, 148]
# 4      [115, 92, 340, 211, 167, 168, 160, 108, 196, 9...
# ...                                                  ...
# 28163                                         [184, 149]
# 28164                                          [126, 58]
# 28165                                              [108]
# 28166                                               [17]
# 28167                                           [70, 27]
#
#                                           count in 2000s  \
# 0      [37, 229, 195, 138, 48, 482, 109, 171, 19, 76,...
# 1      [57, 60, 64, 48, 56, 29, 28, 39, 50, 205, 30, ...
# 2                                          [54, 166, 28]
# 3                                      [206, 22, 76, 42]
# 4      [30, 36, 93, 91, 54, 29, 49, 34, 40, 25, 23, 2...
# ...                                                  ...
# 28163                                           [35, 26]
# 28164                                          [94, 107]
# 28165                                              [137]
# 28166                                              [106]
# 28167                                         [310, 131]
#
#                                  total count up to 2000s
# 0      [239, 1062, 607, 411, 105, 1760, 694, 830, 147...
# 1      [250, 302, 327, 229, 214, 103, 279, 143, 273, ...
# 2                                        [128, 353, 158]
# 3                                   [404, 160, 261, 190]
# 4      [145, 128, 433, 302, 221, 197, 209, 142, 236, ...
# ...                                                  ...
# 28163                                         [219, 175]
# 28164                                         [220, 165]
# 28165                                              [245]
# 28166                                              [123]
# 28167                                         [380, 158]
#
# [28168 rows x 45 columns]

# %%
verbs = set(grouped_frame_df['verb'])
len(verbs)
# Out:
# 5256

# %%
rels = set(grouped_frame_df['relation'])
len(rels)
# Out:
# 18

# %%
support_noun2idx = pickle.load(open('/h/19/jadeleiyu/frame_extension/data/gsn/support_noun2idx.p', 'rb'))
len(support_noun2idx)
# Out:
# 4133

# %%
# Out:
# 0

# %%
import pickle
verb2idx = {v:i for (i, v) in enumerate(verbs)}
pickle.dump(verb2idx, open('/h/19/jadeleiyu/frame_extension/data/gsn/verb2idx.p', 'wb'))

rel2idx = {r:i for (i, r) in enumerate(rels)}
pickle.dump(rel2idx, open('/h/19/jadeleiyu/frame_extension/data/gsn/rel2idx.p', 'wb'))

# %%
# get HistWords embeddings for support nouns
from histwords import get_histwords_embeddings
import pickle

noun2idx = pickle.load(open('/h/19/jadeleiyu/frame_extension/data/gsn/support_noun2idx.p', 'rb'))
get_histwords_embeddings(noun2idx)

# %%
from gsn import learning_df_prep
import pandas as pd
from tqdm import tqdm
list_converter = {'novel nouns next decade': eval, 'novel nouns all future': eval, 'established nouns': eval,
                      'established noun counts': eval}
grouped_frame_df = pd.read_csv('/h/19/jadeleiyu/frame_extension/data/gsn/grouped_frame_df.csv',
                              converters=list_converter)

# %%
learning_df_prep(grouped_frame_df)
# Out:
# 28168it [00:08, 3334.54it/s]
# 28168it [00:08, 3354.83it/s]

# %%
from gsn import get_test_dfs
get_test_dfs()

# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 1000)
training_df = pd.read_csv('/h/19/jadeleiyu/frame_extension/data/gsn/training_df_{}s.csv'.format(1980))
training_df
# Out:
# /h/19/jadeleiyu/frame_extension/frame_extension_venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#                           frame  frame id  \
# 0    accept-dobj                 0
# 1    access-dobj                 1
# 2    accommodate-dobj            2
# 3    achieve-dobj                3
# 4    acknowledge-dobj            4
# 5    acquire-dobj                5
# 6    act-pobj_prep.as            6
# 7    act-pobj_prep.like          7
# 8    activate-dobj               8
# 9    add-dobj                    9
# 10   add-pobj_prep.to            10
# 11   address-dobj                11
# 12   adjust-dobj                 12
# 13   administer-dobj             13
# 14   adopt-dobj                  14
# 15   affect-dobj                 15
# 16   aim-pobj_prep.at            16
# 17   allow-dobj                  17
# 18   allow-pobj_prep.for         18
# 19   analyze-dobj                19
# 20   appear-nsubj                20
# 21   appear-pobj_prep.on         21
# 22   apply-dobj                  22
# 23   apply-pobj_prep.to          23
# 24   approach-dobj               24
# 25   argue-nsubj                 25
# 26   arrive-nsubj                26
# 27   arrive-pobj_prep.in         27
# 28   articulate-dobj             28
# 29   ask-dobj                    29
# 30   ask-pobj_prep.for           30
# 31   assemble-dobj               31
# 32   assess-dobj                 32
# 33   assign-pobj_prep.to         33
# 34   associate-pobj_prep.with    34
# 35   attach-dobj                 35
# 36   attach-pobj_prep.to         36
# 37   attack-dobj                 37
# 38   attract-dobj                38
# 39   avoid-dobj                  39
# 40   back-dobj                   40
# 41   balance-dobj                41
# 42   base-pobj_prep.in           42
# 43   base-pobj_prep.on           43
# 44   be-nsubj                    44
# 45   be-pobj_prep.in             45
# 46   be-pobj_prep.on             46
# 47   become-nsubj                47
# 48   begin-dobj                  48
# 49   begin-nsubj                 49
# 50   benefit-dobj                50
# 51   bind-pobj_prep.to           51
# 52   block-dobj                  52
# 53   blow-dobj                   53
# 54   bring-dobj                  54
# 55   build-dobj                  55
# 56   build-pobj_prep.into        56
# 57   buy-dobj                    57
# 58   call-dobj                   58
# 59   can-nsubj                   59
# 60   capture-dobj                60
# 61   care-dobj                   61
# 62   care-pobj_prep.for          62
# 63   carry-dobj                  63
# 64   catch-dobj                  64
# 65   catch-pobj_prep.in          65
# 66   cause-dobj                  66
# 67   cause-pobj_prep.by          67
# 68   center-pobj_prep.on         68
# 69   challenge-dobj              69
# 70   change-dobj                 70
# 71   change-nsubj                71
# 72   change-pobj_prep.in         72
# 73   characterize-pobj_prep.by   73
# 74   check-dobj                  74
# 75   choose-dobj                 75
# 76   circle-dobj                 76
# 77   cite-pobj_prep.in           77
# 78   clean-dobj                  78
# 79   clear-dobj                  79
# 80   click-dobj                  80
# 81   close-dobj                  81
# 82   close-nsubj                 82
# 83   clutch-dobj                 83
# 84   combine-dobj                84
# 85   combine-pobj_prep.with      85
# 86   come-nsubj                  86
# 87   come-pobj_prep.from         87
# 88   come-pobj_prep.to           88
# 89   come-pobj_prep.with         89
# 90   communicate-pobj_prep.with  90
# 91   compare-dobj                91
# 92   compare-pobj_prep.to        92
# 93   complete-dobj               93
# 94   comprise-dobj               94
# 95   comprise-pobj_prep.of       95
# 96   compute-dobj                96
# 97   concern-pobj_prep.about     97
# 98   conduct-pobj_prep.in        98
# 99   confront-dobj               99
# 100  connect-dobj                100
# 101  connect-pobj_prep.to        101
# 102  consist-pobj_prep.of        102
# 103  construct-dobj              103
# 104  contact-dobj                104
# 105  contain-dobj                105
# 106  contain-nsubj               106
# 107  contain-pobj_prep.in        107
# 108  continue-dobj               108
# 109  continue-nsubj              109
# 110  contribute-pobj_prep.to     110
# 111  control-dobj                111
# 112  convince-dobj               112
# 113  couple-pobj_prep.with       113
# 114  cover-dobj                  114
# 115  cover-pobj_prep.in          115
# 116  crack-dobj                  116
# 117  create-dobj                 117
# 118  create-pobj_prep.by         118
# 119  create-pobj_prep.in         119
# 120  cut-dobj                    120
# 121  damage-dobj                 121
# 122  deal-pobj_prep.with         122
# 123  decrease-dobj               123
# 124  dedicate-pobj_prep.to       124
# 125  define-dobj                 125
# 126  define-pobj_prep.by         126
# 127  define-pobj_prep.in         127
# 128  deliver-dobj                128
# 129  demonstrate-dobj            129
# 130  depend-pobj_prep.on         130
# 131  depict-dobj                 131
# 132  derive-dobj                 132
# 133  derive-pobj_prep.from       133
# 134  describe-dobj               134
# 135  design-dobj                 135
# 136  design-pobj_prep.for        136
# 137  detect-dobj                 137
# 138  determine-dobj              138
# 139  develop-dobj                139
# 140  develop-pobj_prep.by        140
# 141  die-dobj                    141
# 142  die-nsubj                   142
# 143  direct-pobj_prep.at         143
# 144  disappear-pobj_prep.into    144
# 145  discard-dobj                145
# 146  discuss-dobj                146
# 147  display-dobj                147
# 148  display-pobj_prep.in        148
# 149  display-pobj_prep.on        149
# 150  do-dobj                     150
# 151  do-nsubj                    151
# 152  do-pobj_prep.with           152
# 153  dominate-dobj               153
# 154  dominate-pobj_prep.by       154
# 155  drag-dobj                   155
# 156  drain-dobj                  156
# 157  draw-dobj                   157
# 158  draw-pobj_prep.on           158
# 159  dress-pobj_prep.in          159
# 160  drive-dobj                  160
# 161  drive-pobj_prep.by          161
# 162  drive-pobj_prep.to          162
# 163  drop-dobj                   163
# 164  eat-dobj                    164
# 165  edit-dobj                   165
# 166  edit-pobj_prep.by           166
# 167  eliminate-dobj              167
# 168  embed-pobj_prep.in          168
# 169  emerge-pobj_prep.from       169
# 170  emphasize-dobj              170
# 171  empower-dobj                171
# 172  enable-dobj                 172
# 173  encompass-dobj              173
# 174  encounter-dobj              174
# 175  encourage-dobj              175
# 176  end-dobj                    176
# 177  end-nsubj                   177
# 178  engage-dobj                 178
# 179  enhance-dobj                179
# 180  enjoy-dobj                  180
# 181  ensure-dobj                 181
# 182  enter-dobj                  182
# 183  equip-pobj_prep.with        183
# 184  establish-dobj              184
# 185  evaluate-dobj               185
# 186  examine-dobj                186
# 187  exclude-dobj                187
# 188  execute-dobj                188
# 189  exist-nsubj                 189
# 190  expand-dobj                 190
# 191  experience-dobj             191
# 192  explain-dobj                192
# 193  explain-nsubj               193
# 194  exploit-dobj                194
# 195  explore-dobj                195
# 196  expose-dobj                 196
# 197  express-pobj_prep.in        197
# 198  extend-dobj                 198
# 199  extract-dobj                199
# 200  fabricate-dobj              200
# 201  face-dobj                   201
# 202  face-nsubj                  202
# 203  face-pobj_prep.by           203
# 204  face-pobj_prep.with         204
# 205  facilitate-dobj             205
# 206  fail-nsubj                  206
# 207  feature-dobj                207
# 208  feel-dobj                   208
# 209  feel-pobj_prep.like         209
# 210  felt-dobj                   210
# 211  fight-dobj                  211
# 212  fill-dobj                   212
# 213  fill-pobj_prep.with         213
# 214  filter-dobj                 214
# 215  find-dobj                   215
# 216  find-nsubj                  216
# 217  find-pobj_prep.in           217
# 218  find-pobj_prep.on           218
# 219  finish-dobj                 219
# 220  fix-dobj                    220
# 221  focus-pobj_prep.on          221
# 222  follow-dobj                 222
# 223  follow-pobj_prep.by         223
# 224  form-dobj                   224
# 225  frame-dobj                  225
# 226  fund-dobj                   226
# 227  gather-dobj                 227
# 228  generate-dobj               228
# 229  generate-pobj_prep.by       229
# 230  get-dobj                    230
# 231  get-nsubj                   231
# 232  get-pobj_prep.from          232
# 233  get-pobj_prep.into          233
# 234  get-pobj_prep.on            234
# 235  get-pobj_prep.to            235
# 236  give-dobj                   236
# 237  give-iobj                   237
# 238  glance-pobj_prep.at         238
# 239  go-dobj                     239
# 240  go-nsubj                    240
# 241  go-pobj_prep.for            241
# 242  go-pobj_prep.into           242
# 243  go-pobj_prep.of             243
# 244  go-pobj_prep.to             244
# 245  grab-dobj                   245
# 246  grip-dobj                   246
# 247  grow-dobj                   247
# 248  guide-dobj                  248
# 249  hand-dobj                   249
# 250  handle-dobj                 250
# 251  happen-pobj_prep.in         251
# 252  happen-pobj_prep.to         252
# 253  harvest-dobj                253
# 254  have-dobj                   254
# 255  have-nsubj                  255
# 256  head-pobj_prep.for          256
# 257  heal-dobj                   257
# 258  hear-dobj                   258
# 259  help-dobj                   259
# 260  help-pobj_prep.with         260
# 261  hide-dobj                   261
# 262  hire-dobj                   262
# 263  hit-dobj                    263
# 264  hit-nsubj                   264
# 265  hold-dobj                   265
# 266  hold-nsubj                  266
# 267  house-pobj_prep.in          267
# 268  identify-dobj               268
# 269  identify-pobj_prep.as       269
# 270  identify-pobj_prep.by       270
# 271  identify-pobj_prep.in       271
# 272  ignore-dobj                 272
# 273  implement-dobj              273
# 274  implement-pobj_prep.in      274
# 275  import-dobj                 275
# 276  impose-pobj_prep.by         276
# 277  improve-dobj                277
# 278  include-dobj                278
# 279  include-pobj                279
# 280  include-pobj_prep.in        280
# 281  incorporate-dobj            281
# 282  increase-dobj               282
# 283  induce-pobj_prep.by         283
# 284  inform-dobj                 284
# 285  initiate-pobj_prep.by       285
# 286  insert-dobj                 286
# 287  insert-pobj_prep.into       287
# 288  instal-dobj                 288
# 289  instal-nsubj                289
# 290  install-dobj                290
# 291  integrate-dobj              291
# 292  interact-pobj_prep.with     292
# 293  interest-pobj_prep.in       293
# 294  introduce-dobj              294
# 295  invest-pobj_prep.in         295
# 296  investigate-dobj            296
# 297  invoke-dobj                 297
# 298  involve-dobj                298
# 299  involve-pobj_prep.in        299
# 300  involve-pobj_prep.with      300
# 301  join-dobj                   301
# 302  jump-dobj                   302
# 303  keep-dobj                   303
# 304  keep-pobj_prep.on           304
# 305  kill-dobj                   305
# 306  know-dobj                   306
# 307  know-nsubj                  307
# 308  know-pobj_prep.about        308
# 309  know-pobj_prep.as           309
# 310  know-pobj_prep.for          310
# 311  launch-dobj                 311
# 312  lead-pobj_prep.by           312
# 313  lead-pobj_prep.to           313
# 314  learn-dobj                  314
# 315  learn-pobj_prep.about       315
# 316  learn-pobj_prep.in          316
# 317  leave-dobj                  317
# 318  leave-nsubj                 318
# 319  leave-pobj_prep.by          319
# 320  leave-pobj_prep.of          320
# 321  lick-dobj                   321
# 322  limit-dobj                  322
# 323  line-dobj                   323
# 324  line-pobj_prep.with         324
# 325  link-dobj                   325
# 326  link-pobj_prep.to           326
# 327  list-dobj                   327
# 328  list-pobj_prep.in           328
# 329  listen-pobj_prep.to         329
# 330  live-dobj                   330
# 331  live-pobj_prep.in           331
# 332  load-dobj                   332
# 333  locate-dobj                 333
# 334  locate-pobj_prep.in         334
# 335  locate-pobj_prep.on         335
# 336  lock-dobj                   336
# 337  look-dobj                   337
# 338  look-nsubj                  338
# 339  look-pobj_prep.at           339
# 340  look-pobj_prep.for          340
# 341  look-pobj_prep.in           341
# 342  look-pobj_prep.like         342
# 343  lose-dobj                   343
# 344  love-dobj                   344
# 345  maintain-dobj               345
# 346  make-dobj                   346
# 347  make-nsubj                  347
# 348  make-pobj_prep.for          348
# 349  make-pobj_prep.from         349
# 350  make-pobj_prep.of           350
# 351  make-pobj_prep.to           351
# 352  make-pobj_prep.with         352
# 353  manage-dobj                 353
# 354  manipulate-dobj             354
# 355  mark-pobj_prep.by           355
# 356  match-dobj                  356
# 357  maximize-dobj               357
# 358  measure-dobj                358
# 359  measure-pobj_prep.in        359
# 360  mediate-pobj_prep.by        360
# 361  meet-dobj                   361
# 362  meet-nsubj                  362
# 363  meet-pobj_prep.with         363
# 364  mention-dobj                364
# 365  minimize-dobj               365
# 366  miss-dobj                   366
# 367  mix-dobj                    367
# 368  model-dobj                  368
# 369  modify-dobj                 369
# 370  monitor-dobj                370
# 371  motivate-dobj               371
# 372  mount-dobj                  372
# 373  move-dobj                   373
# 374  move-nsubj                  374
# 375  move-pobj_prep.into         375
# 376  move-pobj_prep.to           376
# 377  name-dobj                   377
# 378  navigate-dobj               378
# 379  near-dobj                   379
# 380  need-dobj                   380
# 381  need-nsubj                  381
# 382  need-pobj_prep.for          382
# 383  negotiate-dobj              383
# 384  note-nsubj                  384
# 385  notice-dobj                 385
# 386  observe-pobj_prep.in        386
# 387  obtain-dobj                 387
# 388  obtain-pobj_prep.from       388
# 389  offer-dobj                  389
# 390  offer-pobj_prep.by          390
# 391  open-dobj                   391
# 392  open-nsubj                  392
# 393  operate-dobj                393
# 394  oppose-pobj_prep.to         394
# 395  order-dobj                  395
# 396  overlook-dobj               396
# 397  own-dobj                    397
# 398  pack-dobj                   398
# 399  pack-pobj_prep.with         399
# 400  participate-pobj_prep.in    400
# 401  pass-dobj                   401
# 402  pay-pobj_prep.for           402
# 403  pay-pobj_prep.to            403
# 404  perform-dobj                404
# 405  perform-pobj_prep.in        405
# 406  perform-pobj_prep.on        406
# 407  pick-dobj                   407
# 408  place-dobj                  408
# 409  place-pobj_prep.in          409
# 410  place-pobj_prep.on          410
# 411  play-dobj                   411
# 412  play-nsubj                  412
# 413  play-pobj_prep.by           413
# 414  play-pobj_prep.in           414
# 415  play-pobj_prep.with         415
# 416  point-pobj_prep.at          416
# 417  point-pobj_prep.to          417
# 418  pose-pobj_prep.by           418
# 419  practice-dobj               419
# 420  present-pobj_prep.in        420
# 421  press-dobj                  421
# 422  prevent-dobj                422
# 423  process-dobj                423
# 424  produce-dobj                424
# 425  produce-pobj_prep.by        425
# 426  program-dobj                426
# 427  promote-dobj                427
# 428  protect-dobj                428
# 429  provide-dobj                429
# 430  provide-nsubj               430
# 431  provide-pobj_prep.by        431
# 432  provide-pobj_prep.in        432
# 433  provide-pobj_prep.to        433
# 434  pull-dobj                   434
# 435  pull-pobj_prep.on           435
# 436  purchase-dobj               436
# 437  pursue-dobj                 437
# 438  push-dobj                   438
# 439  put-dobj                    439
# 440  put-nsubj                   440
# 441  put-pobj_prep.in            441
# 442  put-pobj_prep.on            442
# 443  quote-pobj_prep.in          443
# 444  raise-dobj                  444
# 445  range-pobj_prep.to          445
# 446  reach-dobj                  446
# 447  reach-pobj_prep.for         447
# 448  reach-pobj_prep.into        448
# 449  read-dobj                   449
# 450  receive-dobj                450
# 451  receive-nsubj               451
# 452  recognize-dobj              452
# 453  record-dobj                 453
# 454  recover-dobj                454
# 455  reduce-dobj                 455
# 456  reduce-pobj_prep.in         456
# 457  refer-pobj_prep.as          457
# 458  refer-pobj_prep.to          458
# 459  reflect-dobj                459
# 460  reflect-pobj_prep.on        460
# 461  reform-dobj                 461
# 462  regard-dobj                 462
# 463  register-dobj               463
# 464  reinforce-dobj              464
# 465  relate-pobj_prep.to         465
# 466  release-dobj                466
# 467  release-pobj_prep.by        467
# 468  rely-pobj_prep.on           468
# 469  remove-dobj                 469
# 470  remove-pobj_prep.from       470
# 471  repair-dobj                 471
# 472  replace-dobj                472
# 473  replace-pobj_prep.with      473
# 474  report-dobj                 474
# 475  report-pobj_prep.in         475
# 476  represent-dobj              476
# 477  request-dobj                477
# 478  require-dobj                478
# 479  require-pobj_prep.by        479
# 480  require-pobj_prep.for       480
# 481  reserve-pobj_prep.for       481
# 482  reside-pobj_prep.on         482
# 483  resolve-dobj                483
# 484  respond-pobj_prep.to        484
# 485  restore-dobj                485
# 486  result-pobj_prep.in         486
# 487  retrieve-dobj               487
# 488  return-dobj                 488
# 489  return-nsubj                489
# 490  return-pobj_prep.to         490
# 491  reveal-dobj                 491
# 492  review-dobj                 492
# 493  rip-dobj                    493
# 494  roll-dobj                   494
# 495  rotate-dobj                 495
# 496  run-dobj                    496
# 497  run-nsubj                   497
# 498  run-pobj_prep.by            498
# 499  run-pobj_prep.in            499
# 500  run-pobj_prep.on            500
# 501  save-dobj                   501
# 502  saw-dobj                    502
# 503  say-nsubj                   503
# 504  scan-dobj                   504
# 505  screen-dobj                 505
# 506  seal-dobj                   506
# 507  search-dobj                 507
# 508  search-pobj_prep.for        508
# 509  secure-dobj                 509
# 510  see-dobj                    510
# 511  see-pobj_prep.as            511
# 512  see-pobj_prep.in            512
# 513  select-dobj                 513
# 514  select-nsubj                514
# 515  sell-dobj                   515
# 516  send-dobj                   516
# 517  send-pobj_prep.by           517
# 518  send-pobj_prep.to           518
# 519  separate-dobj               519
# 520  serve-dobj                  520
# 521  serve-pobj_prep.as          521
# 522  service-dobj                522
# 523  set-dobj                    523
# 524  set-nsubj                   524
# 525  set-pobj_prep.for           525
# 526  set-pobj_prep.of            526
# 527  set-pobj_prep.on            527
# 528  shape-dobj                  528
# 529  share-dobj                  529
# 530  share-pobj_prep.by          530
# 531  shoot-dobj                  531
# 532  show-dobj                   532
# 533  show-nsubj                  533
# 534  show-pobj_prep.in           534
# 535  shut-dobj                   535
# 536  signal-dobj                 536
# 537  simulate-dobj               537
# 538  sit-pobj_prep.in            538
# 539  sit-pobj_prep.on            539
# 540  slow-dobj                   540
# 541  smooth-dobj                 541
# 542  soak-dobj                   542
# 543  sort-dobj                   543
# 544  sound-pobj_prep.like        544
# 545  span-dobj                   545
# 546  speak-pobj_prep.to          546
# 547  speak-pobj_prep.with        547
# 548  specialize-pobj_prep.in     548
# 549  specify-dobj                549
# 550  specify-pobj_prep.by        550
# 551  specify-pobj_prep.in        551
# 552  spend-pobj_prep.on          552
# 553  spin-dobj                   553
# 554  sport-dobj                  554
# 555  spot-dobj                   555
# 556  sprinkle-pobj_prep.with     556
# 557  stabilize-dobj              557
# 558  stand-nsubj                 558
# 559  star-pobj_prep.at           559
# 560  stare-pobj_prep.at          560
# 561  start-dobj                  561
# 562  start-nsubj                 562
# 563  start-pobj_prep.with        563
# 564  stay-pobj_prep.in           564
# 565  stay-pobj_prep.on           565
# 566  steal-dobj                  566
# 567  step-pobj_prep.into         567
# 568  stick-pobj_prep.in          568
# 569  stir-pobj_prep.in           569
# 570  stop-dobj                   570
# 571  store-dobj                  571
# 572  store-pobj_prep.in          572
# 573  strengthen-dobj             573
# 574  study-dobj                  574
# 575  stuff-pobj_prep.with        575
# 576  suggest-nsubj               576
# 577  support-dobj                577
# 578  support-pobj_prep.by        578
# 579  surround-dobj               579
# 580  surround-pobj_prep.by       580
# 581  switch-dobj                 581
# 582  tackle-dobj                 582
# 583  take-dobj                   583
# 584  take-nsubj                  584
# 585  take-pobj_prep.by           585
# 586  take-pobj_prep.in           586
# 587  take-pobj_prep.of           587
# 588  talk-pobj_prep.about        588
# 589  talk-pobj_prep.to           589
# 590  tap-dobj                    590
# 591  taste-dobj                  591
# 592  teach-dobj                  592
# 593  tell-dobj                   593
# 594  tell-nsubj                  594
# 595  test-dobj                   595
# 596  thank-dobj                  596
# 597  think-pobj_prep.about       597
# 598  throw-pobj_prep.in          598
# 599  tighten-dobj                599
# 600  top-pobj_prep.with          600
# 601  toss-dobj                   601
# 602  touch-dobj                  602
# 603  track-dobj                  603
# 604  trade-dobj                  604
# 605  transfer-pobj_prep.to       605
# 606  transport-dobj              606
# 607  trap-pobj_prep.in           607
# 608  treat-dobj                  608
# 609  treat-pobj_prep.with        609
# 610  trigger-dobj                610
# 611  try-dobj                    611
# 612  turn-dobj                   612
# 613  turn-nsubj                  613
# 614  turn-pobj_prep.into         614
# 615  turn-pobj_prep.on           615
# 616  turn-pobj_prep.to           616
# 617  underlie-dobj               617
# 618  understand-dobj             618
# 619  update-dobj                 619
# 620  use-dobj                    620
# 621  use-nsubj                   621
# 622  use-pobj_prep.as            622
# 623  use-pobj_prep.by            623
# 624  use-pobj_prep.for           624
# 625  use-pobj_prep.in            625
# 626  use-pobj_prep.on            626
# 627  use-pobj_prep.with          627
# 628  view-dobj                   628
# 629  visit-dobj                  629
# 630  wait-pobj_prep.for          630
# 631  walk-pobj_prep.into         631
# 632  walk-pobj_prep.to           632
# 633  want-dobj                   633
# 634  want-nsubj                  634
# 635  watch-dobj                  635
# 636  wear-dobj                   636
# 637  win-dobj                    637
# 638  work-dobj                   638
# 639  work-nsubj                  639
# 640  work-pobj_prep.as           640
# 641  work-pobj_prep.at           641
# 642  work-pobj_prep.for          642
# 643  work-pobj_prep.in           643
# 644  work-pobj_prep.on           644
# 645  work-pobj_prep.with         645
# 646  worry-pobj_prep.about       646
# 647  write-dobj                  647
# 648  write-pobj_prep.by          648
# 649  write-pobj_prep.for         649
# 650  write-pobj_prep.in          650
# 651  write-pobj_prep.to          651
#
#                                                                                       established nouns  \
# 0    ['office', 'post', 'appointment', 'authority', 'help', 'rule', 'call', 'bill']
# 1    ['file', 'record', 'system', 'memory', 'base', 'computer', 'network', 'table']
# 2    ['person', 'people', 'student', 'family', 'child', 'patient', 'vessel', 'guest']
# 3    ['goal', 'objective', 'level', 'balance', 'control', 'target', 'power', 'measure']
# 4    ['authority', 'help', 'support', 'power', 'justice', 'king', 'source', 'failure']
# 5    ['habit', 'power', 'control', 'art', 'stock', 'form', 'material', 'weapon']
# 6    ['guide', 'interpreter', 'secretary', 'mediator', 'judge', 'representative', 'barrier', 'officer']
# 7    ['man', 'child', 'fool', 'people', 'woman', 'boy', 'person', 'baby']
# 8    ['system', 'cell', 'mechanism', 'switch', 'device', 'fiber', 'lymphocyte', 'alarm']
# 9    ['water', 'drop', 'salt', 'sugar', 'weight', 'line', 'milk', 'material']
# 10   ['water', 'beauty', 'collection', 'stock', 'mixture', 'comfort', 'power', 'system']
# 11   ['people', 'house', 'assembly', 'crowd', 'envelope', 'man', 'person', 'court']
# 12   ['screw', 'level', 'balance', 'glass', 'system', 'point', 'control', 'valve']
# 13   ['justice', 'system', 'supper', 'school', 'shock', 'area', 'office', 'comfort']
# 14   ['measure', 'system', 'course', 'child', 'form', 'rule', 'style', 'line']
# 15   ['life', 'system', 'people', 'structure', 'level', 'child', 'area', 'course']
# 16   ['power', 'goal', 'target', 'market', 'head', 'heart', 'control', 'establishment']
# 17   ['room', 'movement', 'control', 'escape', 'water', 'formation', 'study', 'man']
# 18   ['movement', 'control', 'range', 'action', 'study', 'meal', 'rise', 'formation']
# 19   ['structure', 'system', 'case', 'material', 'circuit', 'form', 'mechanism', 'source']
# 20   ['man', 'sign', 'book', 'sun', 'star', 'form', 'christ', 'light']
# 21   ['surface', 'stage', 'side', 'face', 'screen', 'map', 'earth', 'market']
# 22   ['rule', 'formula', 'measure', 'power', 'coat', 'brake', 'model', 'system']
# 23   ['case', 'surface', 'system', 'study', 'person', 'skin', 'area', 'body']
# 24   ['house', 'subject', 'door', 'shore', 'point', 'city', 'place', 'coast']
# 25   ['author', 'people', 'mill', 'smith', 'proponent', 'man', 'theorist', 'case']
# 26   ['guest', 'ship', 'train', 'doctor', 'man', 'help', 'child', 'king']
# 27   ['city', 'camp', 'port', 'course', 'area', 'spring', 'china', 'room']
# 28   ['form', 'goal', 'point', 'rule', 'set', 'structure', 'surface', 'system']
# 29   ['man', 'people', 'help', 'child', 'patient', 'father', 'mother', 'friend']
# 30   ['help', 'food', 'hand', 'support', 'water', 'bread', 'drink', 'appointment']
# 31   ['material', 'people', 'collection', 'body', 'equipment', 'piece', 'set', 'system']
# 32   ['level', 'patient', 'prospect', 'personality', 'child', 'area', 'system', 'power']
# 33   ['class', 'woman', 'school', 'person', 'area', 'individual', 'case', 'place']
# 34   ['system', 'movement', 'level', 'people', 'form', 'life', 'formation', 'failure']
# 35   ['weight', 'piece', 'tube', 'wire', 'rope', 'line', 'friend', 'string']
# 36   ['wall', 'surface', 'side', 'office', 'church', 'house', 'body', 'person']
# 37   ['enemy', 'city', 'man', 'fort', 'ship', 'camp', 'system', 'people']
# 38   ['people', 'support', 'student', 'crowd', 'settler', 'reader', 'tourist', 'worker']
# 39   ['contact', 'action', 'failure', 'formation', 'shock', 'subject', 'food', 'area']
# 40   ['horse', 'water', 'candidate', 'car', 'store', 'winner', 'bill', 'step']
# 41   ['weight', 'book', 'power', 'body', 'scale', 'system', 'bridge', 'line']
# 42   ['city', 'area', 'case', 'measure', 'geneva', 'japan', 'china', 'hospital']
# 43   ['study', 'model', 'system', 'material', 'source', 'story', 'record', 'ground']
# 44   ['man', 'case', 'people', 'life', 'child', 'person', 'woman', 'system']
# 45   ['case', 'hand', 'power', 'place', 'world', 'form', 'contact', 'habit']
# 46   ['side', 'point', 'guard', 'board', 'road', 'ground', 'earth', 'level']
# 47   ['man', 'people', 'child', 'patient', 'life', 'bill', 'person', 'woman']
# 48   ['study', 'life', 'story', 'construction', 'course', 'ascent', 'descent', 'movement']
# 49   ['people', 'world', 'life', 'child', 'movement', 'man', 'sun', 'heart']
# 50   ['people', 'mankind', 'patient', 'class', 'child', 'world', 'farmer', 'individual']
# 51   ['site', 'cell', 'soil', 'surface', 'tree', 'earth', 'life', 'port']
# 52   ['road', 'action', 'channel', 'door', 'street', 'light', 'route', 'transmission']
# 53   ['horn', 'trumpet', 'whistle', 'candle', 'bridge', 'bubble', 'fire', 'cloud']
# 54   ['child', 'home', 'action', 'water', 'people', 'fruit', 'food', 'suit']
# 55   ['house', 'church', 'system', 'bridge', 'wall', 'city', 'road', 'temple']
# 56   ['wall', 'system', 'structure', 'model', 'side', 'house', 'machine', 'fabric']
# 57   ['food', 'house', 'book', 'stock', 'car', 'clothes', 'horse', 'bond']
# 58   ['man', 'friend', 'doctor', 'son', 'people', 'witness', 'system', 'power']
# 59   ['man', 'people', 'woman', 'nobody', 'child', 'person', 'tin', 'individual']
# 60   ['city', 'gun', 'vessel', 'fort', 'ship', 'essence', 'market', 'prey']
# 61   ['straw', 'fig', 'bit', 'pin', 'button', 'people', 'snap', 'person']
# 62   ['child', 'patient', 'people', 'baby', 'person', 'family', 'mother', 'animal']
# 63   ['weight', 'water', 'gun', 'passenger', 'arm', 'bag', 'measure', 'point']
# 64   ['fish', 'train', 'fire', 'hold', 'ball', 'bird', 'light', 'fly']
# 65   ['trap', 'arm', 'net', 'web', 'snare', 'water', 'mesh', 'hand']
# 66   ['failure', 'rise', 'formation', 'alarm', 'movement', 'fall', 'shift', 'decline']
# 67   ['action', 'failure', 'movement', 'fire', 'wind', 'fall', 'water', 'fungus']
# 68   ['point', 'line', 'city', 'area', 'family', 'nucleus', 'man', 'life']
# 69   ['authority', 'power', 'system', 'world', 'structure', 'man', 'rule', 'action']
# 70   ['subject', 'course', 'place', 'system', 'clothes', 'form', 'structure', 'life']
# 71   ['people', 'world', 'face', 'wind', 'light', 'life', 'man', 'form']
# 72   ['form', 'course', 'structure', 'life', 'system', 'case', 'world', 'light']
# 73   ['formation', 'level', 'movement', 'structure', 'form', 'accumulation', 'set', 'failure']
# 74   ['spread', 'movement', 'power', 'course', 'action', 'record', 'level', 'rise']
# 75   ['president', 'course', 'place', 'subject', 'form', 'site', 'side', 'representative']
# 76   ['earth', 'sun', 'room', 'field', 'house', 'area', 'city', 'fire']
# 77   ['support', 'table', 'book', 'case', 'paper', 'study', 'connection', 'ref']
# 78   ['house', 'room', 'mess', 'surface', 'street', 'floor', 'place', 'boot']
# 79   ['ground', 'table', 'point', 'road', 'area', 'field', 'street', 'head']
# 80   ['heel', 'button', 'tongue', 'mouse', 'shutter', 'box', 'finger', 'camera']
# 81   ['door', 'gap', 'book', 'window', 'gate', 'mouth', 'valve', 'circuit']
# 82   ['door', 'valve', 'mouth', 'gate', 'school', 'window', 'lip', 'bank']
# 83   ['arm', 'hand', 'head', 'bag', 'side', 'bottle', 'heart', 'hair']
# 84   ['power', 'form', 'study', 'weight', 'material', 'action', 'system', 'site']
# 85   ['water', 'power', 'system', 'base', 'iron', 'study', 'form', 'movement']
# 86   ['man', 'people', 'spring', 'light', 'christ', 'child', 'father', 'sun']
# 87   ['source', 'family', 'home', 'side', 'heart', 'hand', 'place', 'area']
# 88   ['house', 'power', 'point', 'place', 'life', 'throne', 'hand', 'light']
# 89   ['power', 'hand', 'wife', 'family', 'cloud', 'enemy', 'father', 'story']
# 90   ['people', 'world', 'computer', 'friend', 'person', 'patient', 'child', 'system']
# 91   ['fig', 'system', 'table', 'level', 'structure', 'weight', 'form', 'set']
# 92   ['control', 'system', 'child', 'area', 'level', 'cell', 'patient', 'case']
# 93   ['course', 'study', 'cycle', 'school', 'circuit', 'form', 'circle', 'book']
# 94   ['system', 'area', 'representative', 'person', 'family', 'body', 'class', 'book']
# 95   ['representative', 'people', 'individual', 'person', 'cell', 'student', 'woman', 'officer']
# 96   ['area', 'measure', 'weight', 'table', 'power', 'matrix', 'root', 'point']
# 97   ['child', 'people', 'security', 'threat', 'image', 'life', 'level', 'power']
# 98   ['area', 'field', 'setting', 'person', 'school', 'city', 'connection', 'style']
# 99   ['world', 'people', 'man', 'enemy', 'student', 'teacher', 'woman', 'person']
# 100  ['point', 'link', 'line', 'rod', 'city', 'center', 'wire', 'system']
# 101  ['system', 'line', 'source', 'circuit', 'computer', 'network', 'earth', 'pump']
# 102  ['cell', 'person', 'layer', 'line', 'representative', 'piece', 'house', 'mixture']
# 103  ['model', 'system', 'building', 'line', 'road', 'table', 'house', 'bridge']
# 104  ['office', 'people', 'surface', 'person', 'doctor', 'physician', 'center', 'lens']
# 105  ['water', 'material', 'cell', 'proportion', 'inhabitant', 'nucleus', 'seed', 'salt']
# 106  ['book', 'water', 'cell', 'world', 'blood', 'body', 'library', 'soil']
# 107  ['book', 'table', 'water', 'vessel', 'paper', 'bill', 'tube', 'document']
# 108  ['study', 'course', 'fight', 'line', 'life', 'story', 'system', 'retreat']
# 109  ['system', 'life', 'people', 'movement', 'patient', 'man', 'game', 'action']
# 110  ['support', 'formation', 'decline', 'comfort', 'life', 'failure', 'magazine', 'rise']
# 111  ['movement', 'action', 'life', 'level', 'system', 'power', 'market', 'pest']
# 112  ['people', 'reader', 'world', 'man', 'person', 'patient', 'court', 'king']
# 113  ['power', 'system', 'control', 'failure', 'threat', 'study', 'measure', 'level']
# 114  ['area', 'range', 'face', 'surface', 'field', 'ground', 'head', 'body']
# 115  ['book', 'study', 'course', 'place', 'blood', 'table', 'paper', 'case']
# 116  ['whip', 'nut', 'shell', 'head', 'bone', 'wall', 'ice', 'heel']
# 117  ['world', 'system', 'image', 'form', 'man', 'structure', 'market', 'life']
# 118  ['man', 'system', 'people', 'action', 'movement', 'power', 'dam', 'instrument']
# 119  ['image', 'place', 'world', 'area', 'course', 'form', 'heart', 'life']
# 120  ['head', 'tree', 'wood', 'hair', 'line', 'retreat', 'piece', 'timber']
# 121  ['cell', 'structure', 'surface', 'system', 'vessel', 'wall', 'skin', 'ship']
# 122  ['subject', 'people', 'case', 'child', 'life', 'material', 'system', 'world']
# 123  ['level', 'resistance', 'return', 'power', 'weight', 'area', 'diameter', 'proportion']
# 124  ['memory', 'lady', 'study', 'king', 'sun', 'life', 'john', 'friend']
# 125  ['area', 'power', 'system', 'goal', 'structure', 'objective', 'scope', 'class']
# 126  ['line', 'rule', 'set', 'system', 'point', 'formula', 'bureau', 'court']
# 127  ['fig', 'table', 'study', 'art', 'book', 'case', 'chap', 'system']
# 128  ['baby', 'child', 'paper', 'soul', 'people', 'course', 'fire', 'arm']
# 129  ['power', 'point', 'connection', 'level', 'action', 'support', 'structure', 'range']
# 130  ['level', 'power', 'structure', 'material', 'form', 'system', 'action', 'source']
# 131  ['life', 'man', 'woman', 'world', 'story', 'people', 'action', 'subject']
# 132  ['power', 'formula', 'authority', 'support', 'form', 'model', 'measure', 'rule']
# 133  ['source', 'study', 'cell', 'model', 'system', 'rock', 'root', 'form']
# 134  ['system', 'structure', 'life', 'form', 'action', 'person', 'case', 'circle']
# 135  ['system', 'building', 'structure', 'study', 'circuit', 'machine', 'house', 'model']
# 136  ['child', 'student', 'people', 'study', 'reader', 'school', 'person', 'woman']
# 137  ['sign', 'movement', 'case', 'point', 'level', 'wave', 'source', 'carrier']
# 138  ['level', 'point', 'course', 'form', 'structure', 'weight', 'action', 'area']
# 139  ['system', 'power', 'model', 'habit', 'form', 'style', 'structure', 'personality']
# 140  ['author', 'engine', 'motor', 'scientist', 'bureau', 'people', 'school', 'system']
# 141  ['man', 'maid', 'life', 'game', 'child', 'people', 'maker', 'world']
# 142  ['father', 'man', 'mother', 'wife', 'christ', 'child', 'patient', 'people']
# 143  ['child', 'person', 'woman', 'target', 'individual', 'people', 'objective', 'point']
# 144  ['room', 'house', 'wood', 'crowd', 'kitchen', 'bush', 'water', 'cloud']
# 145  ['layer', 'system', 'material', 'water', 'form', 'card', 'washing', 'seed']
# 146  ['subject', 'point', 'case', 'measure', 'system', 'form', 'book', 'structure']
# 147  ['power', 'sign', 'flag', 'beauty', 'structure', 'form', 'banner', 'image']
# 148  ['fig', 'table', 'window', 'form', 'case', 'construction', 'action', 'room']
# 149  ['screen', 'oscilloscope', 'side', 'monitor', 'wall', 'board', 'table', 'subject']
# 150  ['justice', 'action', 'bit', 'study', 'office', 'piece', 'child', 'life']
# 151  ['man', 'people', 'child', 'woman', 'father', 'person', 'mother', 'boy']
# 152  ['life', 'people', 'case', 'man', 'hand', 'child', 'woman', 'subject']
# 153  ['life', 'world', 'market', 'field', 'area', 'city', 'system', 'movement']
# 154  ['power', 'woman', 'class', 'communist', 'church', 'people', 'tower', 'system']
# 155  ['foot', 'body', 'leg', 'chain', 'man', 'boat', 'anchor', 'cart']
# 156  ['area', 'water', 'glass', 'cup', 'swamp', 'blood', 'site', 'valley']
# 157  ['line', 'sword', 'water', 'curtain', 'blood', 'parallel', 'foot', 'map']
# 158  ['bank', 'paper', 'side', 'glove', 'source', 'map', 'surface', 'scale']
# 159  ['clothes', 'suit', 'costume', 'uniform', 'robe', 'coat', 'gown', 'garment']
# 160  ['car', 'enemy', 'home', 'horse', 'cattle', 'automobile', 'wedge', 'nail']
# 161  ['motor', 'wind', 'engine', 'power', 'man', 'turbine', 'wheel', 'belt']
# 162  ['house', 'station', 'hotel', 'place', 'wall', 'hospital', 'door', 'airport']
# 163  ['bomb', 'subject', 'anchor', 'hand', 'head', 'line', 'arm', 'gun']
# 164  ['food', 'bread', 'meat', 'meal', 'dinner', 'fruit', 'breakfast', 'supper']
# 165  ['paper', 'book', 'newspaper', 'magazine', 'collection', 'material', 'file', 'film']
# 166  ['smith', 'son', 'wright', 'hill', 'miller', 'green', 'hall', 'bell']
# 167  ['source', 'barrier', 'hazard', 'threat', 'system', 'material', 'form', 'middleman']
# 168  ['matrix', 'wall', 'concrete', 'material', 'structure', 'rock', 'skin', 'system']
# 169  ['study', 'water', 'wood', 'egg', 'room', 'cloud', 'house', 'stage']
# ...
# 242  ['pavilion', 'trailer']
# 243  ['story', 'resistance']
# 244  ['tab', 'folder']
# 245  ['gear', 'backpack']
# 246  ['phone', 'glass']
# 247  ['library', 'arm']
# 248  ['employee', 'router']
# 249  ['camera', 'canteen']
# 250  ['link', 'prey']
# 251  ['store', 'step']
# 252  ['grandmother', 'beast']
# 253  ['organ', 'apple']
# 254  ['handler', 'burger']
# 255  ['keyboard', 'button']
# 256  ['site', 'desk']
# 257  ['light', 'family']
# 258  ['threshold', 'mouth']
# 259  ['skin', 'smoker']
# 260  ['family', 'chair']
# 261  ['file', 'column']
# 262  ['auditor', 'president']
# 263  ['store', 'slope']
# 264  ['truck', 'user']
# 265  ['adult', 'pump']
# 266  ['container', 'array']
# 267  ['prison', 'warehouse']
# 268  ['tag', 'stakeholder']
# 269  ['worker', 'black']
# 270  ['family', 'screening']
# 271  ['box', 'setting']
# 272  ['gun', 'soldier']
# 273  ['site', 'gate']
# 274  ['layer', 'package']
# 275  ['table', 'java']
# 276  ['actor', 'surgery']
# 277  ['screening', 'swing']
# 278  ['menu', 'clip']
# 279  ['internet', 'vat']
# 280  ['string', 'tool']
# 281  ['tool', 'fiber']
# 282  ['bun', 'gas']
# 283  ['lymphocyte', 'layer']
# 284  ['seller', 'source']
# 285  ['binding', 'master']
# 286  ['tag', 'button']
# 287  ['field', 'book']
# 288  ['tool', 'base']
# 289  ['window', 'font']
# 290  ['driver', 'patch']
# 291  ['baseball', 'person']
# 292  ['food', 'animal']
# 293  ['link', 'image']
# 294  ['site', 'predator']
# 295  ['woman', 'vehicle']
# 296  ['channel', 'judge']
# 297  ['menu', 'call']
# 298  ['kid', 'celebrity']
# 299  ['hobby', 'setup']
# 300  ['collection', 'market']
# 301  ['theater', 'case']
# 302  ['car', 'bed']
# 303  ['computer', 'kit']
# 304  ['woman', 'wife']
# 305  ['tank', 'astronaut']
# 306  ['journalist', 'makeup']
# 307  ['archer', 'recipient']
# 308  ['hazard', 'herb']
# 309  ['internet', 'cache']
# 310  ['film', 'personality']
# 311  ['shuttle', 'box']
# 312  ['guy', 'facilitator']
# 313  ['trapping', 'upstairs']
# 314  ['interface', 'computer']
# 315  ['internet', 'mechanic']
# 316  ['step', 'patient']
# 317  ['menu', 'pharmacy']
# 318  ['bush', 'shift']
# 319  ['truck', 'user']
# 320  ['row', 'bar']
# 321  ['ball', 'pussy']
# 322  ['user', 'model']
# 323  ['tin', 'table']
# 324  ['pillar', 'locker']
# 325  ['local', 'user']
# 326  ['record', 'marker']
# 327  ['level', 'implement']
# 328  ['panel', 'scope']
# 329  ['city', 'channel']
# 330  ['human', 'baby']
# 331  ['rise', 'wheelchair']
# 332  ['assembly', 'module']
# 333  ['folder', 'marker']
# 334  ['menu', 'bar']
# 335  ['computer', 'menu']
# 336  ['key', 'woman']
# 337  ['dad', 'buddy']
# 338  ['cell', 'white']
# 339  ['bobby', 'interface']
# 340  ['tag', 'node']
# 341  ['cabinet', 'menu']
# 342  ['buck', 'truck']
# 343  ['packet', 'ranch']
# 344  ['area', 'chocolate']
# 345  ['filling', 'server']
# 346  ['upgrade', 'antenna']
# 347  ['bus', 'daddy']
# 348  ['camera', 'ride']
# 349  ['wrapper', 'composite']
# 350  ['node', 'key']
# 351  ['elevator', 'row']
# 352  ['reader', 'laser']
# 353  ['model', 'link']
# 354  ['embryo', 'memory']
# 355  ['image', 'statue']
# 356  ['heel', 'boot']
# 357  ['convenience', 'transmission']
# 358  ['container', 'quilt']
# 359  ['mouse', 'adult']
# 360  ['family', 'institution']
# 361  ['local', 'attorney']
# 362  ['swim', 'tongue']
# 363  ['prospect', 'general']
# 364  ['press', 'personality']
# 365  ['binding', 'support']
# 366  ['file', 'dad']
# 367  ['apple', 'control']
# 368  ['level', 'stage']
# 369  ['architecture', 'display']
# 370  ['employee', 'worker']
# 371  ['player', 'soldier']
# 372  ['hole', 'partition']
# 373  ['aisle', 'recipient']
# 374  ['bill', 'flag']
# 375  ['extension', 'niche']
# 376  ['layer', 'bedroom']
# 377  ['layer', 'cat']
# 378  ['internet', 'life']
# 379  ['peak', 'ruin']
# 380  ['beer', 'refresher']
# 381  ['athlete', 'support']
# 382  ['sequence', 'block']
# 383  ['target', 'range']
# 384  ['young', 'worker']
# 385  ['foot', 'link']
# 386  ['map', 'device']
# 387  ['patch', 'driver']
# 388  ['fitting', 'monitor']
# 389  ['carrot', 'storage']
# 390  ['internet', 'web']
# 391  ['manager', 'tab']
# 392  ['park', 'document']
# 393  ['platform', 'server']
# 394  ['reader', 'player']
# 395  ['burger', 'appetizer']
# 396  ['airport', 'superior']
# 397  ['knife', 'table']
# 398  ['peanut', 'shoe']
# 399  ['tourist', 'flower']
# 400  ['place', 'set']
# 401  ['platter', 'interface']
# 402  ['date', 'kid']
# 403  ['site', 'salesperson']
# 404  ['screen', 'school']
# 405  ['frame', 'film']
# 406  ['human', 'measure']
# 407  ['backpack', 'dinner']
# 408  ['rack', 'phone']
# 409  ['briefcase', 'sign']
# 410  ['user', 'hold']
# 411  ['dress', 'clip']
# 412  ['market', 'tape']
# 413  ['white', 'wood']
# 414  ['car', 'cup']
# 415  ['somebody', 'student']
# 416  ['center', 'bag']
# 417  ['phone', 'monitor']
# 418  ['rule', 'internet']
# 419  ['line', 'model']
# 420  ['woman', 'tab']
# 421  ['pump', 'screen']
# 422  ['driver', 'pathogen']
# 423  ['body', 'face']
# 424  ['tv', 'kid']
# 425  ['fox', 'scribe']
# 426  ['controller', 'module']
# 427  ['body', 'memory']
# 428  ['reef', 'turtle']
# 429  ['button', 'web']
# 430  ['office', 'internet']
# 431  ['tutor', 'pharmacist']
# 432  ['sheet', 'face']
# 433  ['medium', 'cell']
# 434  ['jar', 'sandwich']
# 435  ['beard', 'sweatshirt']
# 436  ['school', 'television']
# 437  ['school', 'ministry']
# 438  ['carrot', 'control']
# 439  ['laundry', 'bottom']
# 440  ['berry', 'guy']
# 441  ['blender', 'holster']
# 442  ['tv', 'grill']
# 443  ['carpenter', 'woman']
# 444  ['sibling', 'cub']
# 445  ['teacher', 'film']
# 446  ['campground', 'major']
# 447  ['handbag', 'tea']
# 448  ['pouch', 'jacket']
# 449  ['site', 'span']
# 450  ['fax', 'tape']
# 451  ['router', 'nurse']
# 452  ['market', 'indicator']
# 453  ['disc', 'video']
# 454  ['plant', 'foundation']
# 455  ['pathogen', 'decline']
# 456  ['adult', 'school']
# 457  ['loop', 'file']
# 458  ['channel', 'cover']
# 459  ['episode', 'threat']
# 460  ['area', 'institution']
# 461  ['bond', 'action']
# 462  ['internet', 'array']
# 463  ['patient', 'user']
# 464  ['contact', 'style']
# 465  ['package', 'web']
# 466  ['fiber', 'model']
# 467  ['root', 'microorganism']
# 468  ['story', 'library']
# 469  ['driver', 'marker']
# 470  ['chain', 'menu']
# 471  ['heart', 'table']
# 472  ['map', 'handset']
# 473  ['nucleus', 'device']
# 474  ['center', 'radio']
# 475  ['model', 'file']
# 476  ['display', 'printer']
# 477  ['connection', 'accommodation']
# 478  ['controller', 'header']
# 479  ['developer', 'layer']
# 480  ['module', 'screening']
# 481  ['player', 'system']
# 482  ['computer', 'network']
# 483  ['host', 'barrier']
# 484  ['mail', 'book']
# 485  ['drive', 'box']
# 486  ['interface', 'swing']
# 487  ['package', 'sword']
# 488  ['image', 'structure']
# 489  ['athlete', 'material']
# 490  ['cockpit', 'manager']
# 491  ['key', 'clothes']
# 492  ['portfolio', 'package']
# 493  ['stock', 'head']
# 494  ['singer', 'record']
# 495  ['model', 'rim']
# 496  ['site', 'filter']
# 497  ['mixer', 'user']
# 498  ['newspaper', 'line']
# 499  ['thread', 'loop']
# 500  ['node', 'router']
# 501  ['owl', 'buddy']
# 502  ['video', 'shock']
# 503  ['cassie', 'china']
# 504  ['print', 'port']
# 505  ['tool', 'form']
# 506  ['juvenile', 'side']
# 507  ['net', 'purse']
# 508  ['switch', 'node']
# 509  ['computer', 'network']
# 510  ['server', 'tattoo']
# 511  ['site', 'candidate']
# 512  ['menu', 'sport']
# 513  ['interface', 'tag']
# 514  ['row', 'point']
# 515  ['bike', 'crack']
# 516  ['trap', 'astronaut']
# 517  ['satellite', 'fax']
# 518  ['layer', 'medium']
# 519  ['player', 'user']
# 520  ['ingredient', 'onion']
# 521  ['compass', 'net']
# 522  ['computer', 'child']
# 523  ['phone', 'header']
# 524  ['tool', 'tv']
# 525  ['user', 'site']
# 526  ['story', 'actor']
# 527  ['control', 'setting']
# 528  ['memory', 'prospect']
# 529  ['document', 'drive']
# 530  ['doctor', 'art']
# 531  ['demonstrator', 'blank']
# 532  ['implant', 'viewer']
# 533  ['employer', 'martin']
# 534  ['orange', 'control']
# 535  ['server', 'down']
# 536  ['call', 'rise']
# 537  ['layer', 'control']
# 538  ['warehouse', 'cafeteria']
# 539  ['desktop', 'bumper']
# 540  ['accumulation', 'aircraft']
# 541  ['ride', 'tie']
# 542  ['body', 'tub']
# 543  ['bill', 'field']
# 544  ['kid', 'line']
# 545  ['stage', 'row']
# 546  ['back', 'detective']
# 547  ['nurse', 'reporter']
# 548  ['style', 'wine']
# 549  ['server', 'flag']
# 550  ['sponsor', 'level']
# 551  ['interface', 'tab']
# 552  ['grade', 'grocery']
# 553  ['doctor', 'lock']
# 554  ['glass', 'record']
# 555  ['light', 'hyena']
# 556  ['pecan', 'walnut']
# 557  ['weight', 'formation']
# 558  ['guy', 'cream']
# 559  ['fan', 'arm']
# 560  ['cloud', 'mountain']
# 561  ['document', 'window']
# 562  ['loop', 'mess']
# 563  ['frame', 'window']
# 564  ['fall', 'accommodation']
# 565  ['case', 'plane']
# 566  ['camera', 'pear']
# 567  ['stall', 'boot']
# 568  ['world', 'oven']
# 569  ['yeast', 'basil']
# 570  ['date', 'launch']
# 571  ['packet', 'mail']
# 572  ['server', 'folder']
# 573  ['blood', 'net']
# 574  ['reception', 'barrier']
# 575  ['crab', 'paste']
# 576  ['hart', 'nutrient']
# 577  ['automation', 'entrepreneur']
# 578  ['vendor', 'architecture']
# 579  ['transmission', 'beach']
# 580  ['chicken', 'artifact']
# 581  ['seat', 'packet']
# 582  ['threat', 'goal']
# 583  ['mound', 'garlic']
# 584  ['seller', 'binding']
# 585  ['panel', 'network']
# 586  ['arena', 'tandem']
# 587  ['earth', 'twin']
# 588  ['weight', 'construction']
# 589  ['bobby', 'molly']
# 590  ['shoe', 'screen']
# 591  ['tomato', 'wind']
# 592  ['puppy', 'balance']
# 593  ['window', 'recipient']
# 594  ['adult', 'drawer']
# 595  ['accommodation', 'ligament']
# 596  ['centre', 'support']
# 597  ['john', 'piece']
# 598  ['game', 'patch']
# 599  ['lace', 'cable']
# 600  ['sugar', 'onion']
# 601  ['window', 'towel']
# 602  ['makeup', 'mouse']
# 603  ['site', 'control']
# 604  ['system', 'measure']
# 605  ['video', 'foundation']
# 606  ['guest', 'individual']
# 607  ['elevator', 'bubble']
# 608  ['doctor', 'flash']
# 609  ['formula', 'control']
# 610  ['round', 'boom']
# 611  ['phone', 'tongue']
# 612  ['phone', 'lemon']
# 613  ['headlight', 'phone']
# 614  ['adult', 'mother']
# 615  ['siren', 'monitor']
# 616  ['guy', 'phone']
# 617  ['coupling', 'spread']
# 618  ['ministry', 'internet']
# 619  ['link', 'site']
# 620  ['picker', 'java']
# 621  ['network', 'setting']
# 622  ['compress', 'class']
# 623  ['router', 'layer']
# 624  ['printer', 'user']
# 625  ['chip', 'monitor']
# 626  ['link', 'food']
# 627  ['printer', 'heart']
# 628  ['folder', 'channel']
# 629  ['mall', 'channel']
# 630  ['organ', 'daddy']
# 631  ['elevator', 'closet']
# 632  ['toilet', 'cafe']
# 633  ['site', 'shower']
# 634  ['billy', 'station']
# 635  ['medium', 'golf']
# 636  ['ensemble', 'monitor']
# 637  ['buck', 'film']
# 638  ['counter', 'beat']
# 639  ['network', 'filter']
# 640  ['coach', 'economist']
# 641  ['magazine', 'cafe']
# 642  ['employee', 'attorney']
# 643  ['supermarket', 'marketplace']
# 644  ['quilt', 'bike']
# 645  ['style', 'server']
# 646  ['enemy', 'patient']
# 647  ['tag', 'interface']
# 648  ['guy', 'designer']
# 649  ['web', 'lawyer']
# 650  ['independent', 'marker']
# 651  ['console', 'medium']

# %%
import pandas as pd
frame_df = pd.read_csv('/h/19/jadeleiyu/frame_extension/data/gsn/frame_eval_df_{}s.csv'.format(1960))
frame_df
# Out:
#      Unnamed: 0                       frame  \
# 0    0           accommodate-dobj
# 1    1           achieve-dobj
# 2    2           add-dobj
# 3    3           add-pobj_prep.to
# 4    4           address-dobj
# 5    5           aim-pobj_prep.at
# 6    6           allow-dobj
# 7    7           allow-pobj_prep.for
# 8    8           analyze-dobj
# 9    9           appear-nsubj
# 10   10          appear-pobj_prep.on
# 11   11          assemble-dobj
# 12   12          assign-pobj_prep.to
# 13   13          associate-pobj_prep.with
# 14   14          attach-pobj_prep.to
# 15   15          attract-dobj
# 16   16          avoid-dobj
# 17   17          balance-dobj
# 18   18          base-pobj_prep.on
# 19   19          be-nsubj
# 20   20          be-pobj_prep.in
# 21   21          be-pobj_prep.on
# 22   22          bind-pobj_prep.in
# 23   23          bind-pobj_prep.to
# 24   24          block-dobj
# 25   25          bring-dobj
# 26   26          build-dobj
# 27   27          buy-dobj
# 28   28          call-dobj
# 29   29          capture-dobj
# 30   30          carry-dobj
# 31   31          cause-pobj_prep.by
# 32   32          challenge-dobj
# 33   33          change-dobj
# 34   34          check-dobj
# 35   35          choose-dobj
# 36   36          close-dobj
# 37   37          close-nsubj
# 38   38          combine-dobj
# 39   39          come-pobj_prep.to
# 40   40          come-pobj_prep.with
# 41   41          communicate-pobj_prep.with
# 42   42          compare-dobj
# 43   43          compare-pobj_prep.to
# 44   44          complete-dobj
# 45   45          compute-dobj
# 46   46          confront-dobj
# 47   47          connect-dobj
# 48   48          connect-pobj_prep.to
# 49   49          consist-pobj_prep.of
# 50   50          construct-dobj
# 51   51          contain-dobj
# 52   52          control-dobj
# 53   53          copy-dobj
# 54   54          cover-dobj
# 55   55          crack-dobj
# 56   56          create-dobj
# 57   57          create-pobj_prep.by
# 58   58          create-pobj_prep.in
# 59   59          deal-pobj_prep.with
# 60   60          define-dobj
# 61   61          define-pobj_prep.by
# 62   62          deliver-dobj
# 63   63          derive-dobj
# 64   64          derive-pobj_prep.from
# 65   65          describe-dobj
# 66   66          design-dobj
# 67   67          design-pobj_prep.for
# 68   68          detect-dobj
# 69   69          develop-dobj
# 70   70          display-dobj
# 71   71          display-pobj_prep.in
# 72   72          do-dobj
# 73   73          drag-dobj
# 74   74          draw-pobj_prep.on
# 75   75          drive-dobj
# 76   76          drop-dobj
# 77   77          eat-dobj
# 78   78          edit-pobj_prep.by
# 79   79          embed-pobj_prep.in
# 80   80          enable-dobj
# 81   81          encourage-dobj
# 82   82          ensure-dobj
# 83   83          enter-dobj
# 84   84          equip-pobj_prep.with
# 85   85          evaluate-dobj
# 86   86          expand-dobj
# 87   87          experience-dobj
# 88   88          experience-pobj_prep.by
# 89   89          exploit-dobj
# 90   90          explore-dobj
# 91   91          export-dobj
# 92   92          face-dobj
# 93   93          face-pobj_prep.by
# 94   94          fail-nsubj
# 95   95          fill-dobj
# 96   96          find-dobj
# 97   97          find-pobj_prep.in
# 98   98          find-pobj_prep.on
# 99   99          follow-pobj_prep.by
# 100  100         form-dobj
# 101  101         generate-dobj
# 102  102         generate-pobj_prep.by
# 103  103         get-dobj
# 104  104         get-pobj_prep.to
# 105  105         go-nsubj
# 106  106         go-pobj_prep.to
# 107  107         grab-dobj
# 108  108         handle-dobj
# 109  109         have-dobj
# 110  110         have-nsubj
# 111  111         head-pobj_prep.for
# 112  112         help-dobj
# 113  113         hire-dobj
# 114  114         hit-dobj
# 115  115         identify-dobj
# 116  116         import-dobj
# 117  117         improve-dobj
# 118  118         include-dobj
# 119  119         include-pobj
# 120  120         incorporate-dobj
# 121  121         increase-dobj
# 122  122         induce-pobj_prep.by
# 123  123         inform-dobj
# 124  124         initiate-dobj
# 125  125         insert-dobj
# 126  126         instal-dobj
# 127  127         install-dobj
# 128  128         introduce-dobj
# 129  129         invest-pobj_prep.in
# 130  130         involve-dobj
# 131  131         involve-pobj_prep.in
# 132  132         kill-dobj
# 133  133         know-pobj_prep.as
# 134  134         launch-dobj
# 135  135         learn-dobj
# 136  136         leave-dobj
# 137  137         link-dobj
# 138  138         list-dobj
# 139  139         load-dobj
# 140  140         locate-dobj
# 141  141         locate-pobj_prep.in
# 142  142         locate-pobj_prep.on
# 143  143         look-pobj_prep.at
# 144  144         look-pobj_prep.for
# 145  145         maintain-dobj
# 146  146         make-dobj
# 147  147         manage-dobj
# 148  148         manipulate-dobj
# 149  149         match-dobj
# 150  150         modify-dobj
# 151  151         move-dobj
# 152  152         move-pobj_prep.to
# 153  153         need-dobj
# 154  154         nurse-dobj
# 155  155         observe-pobj_prep.in
# 156  156         offer-dobj
# 157  157         offer-pobj_prep.by
# 158  158         open-dobj
# 159  159         operate-dobj
# 160  160         oppose-pobj_prep.to
# 161  161         own-dobj
# 162  162         participate-pobj_prep.in
# 163  163         perform-dobj
# 164  164         pick-dobj
# 165  165         place-pobj_prep.on
# 166  166         play-dobj
# 167  167         predict-dobj
# 168  168         press-dobj
# 169  169         produce-dobj
# 170  170         produce-pobj_prep.by
# 171  171         promote-dobj
# 172  172         protect-dobj
# 173  173         provide-dobj
# 174  174         provide-nsubj
# 175  175         provide-pobj_prep.by
# 176  176         pull-dobj
# 177  177         purchase-dobj
# 178  178         pursue-dobj
# 179  179         put-pobj_prep.in
# 180  180         put-pobj_prep.on
# 181  181         quote-pobj_prep.in
# 182  182         range-pobj_prep.to
# 183  183         reach-pobj_prep.for
# 184  184         read-dobj
# 185  185         reduce-dobj
# 186  186         refer-pobj_prep.to
# 187  187         reflect-dobj
# 188  188         regard-dobj
# 189  189         relate-pobj_prep.to
# 190  190         release-dobj
# 191  191         rely-pobj_prep.on
# 192  192         remove-dobj
# 193  193         replace-dobj
# 194  194         represent-dobj
# 195  195         request-dobj
# 196  196         require-dobj
# 197  197         require-pobj_prep.by
# 198  198         reside-pobj_prep.in
# 199  199         respond-pobj_prep.to
# 200  200         result-pobj_prep.in
# 201  201         return-dobj
# 202  202         return-pobj_prep.to
# 203  203         reveal-dobj
# 204  204         run-dobj
# 205  205         run-pobj_prep.on
# 206  206         save-dobj
# 207  207         scan-dobj
# 208  208         search-dobj
# 209  209         search-pobj_prep.for
# 210  210         see-dobj
# 211  211         see-pobj_prep.as
# 212  212         select-dobj
# 213  213         sell-dobj
# 214  214         send-dobj
# 215  215         send-pobj_prep.by
# 216  216         send-pobj_prep.to
# 217  217         serve-dobj
# 218  218         set-dobj
# 219  219         share-dobj
# 220  220         share-pobj_prep.by
# 221  221         shoot-dobj
# 222  222         show-dobj
# 223  223         shut-dobj
# 224  224         span-dobj
# 225  225         specify-dobj
# 226  226         start-dobj
# 227  227         start-pobj_prep.with
# 228  228         stop-dobj
# 229  229         store-dobj
# 230  230         store-pobj_prep.in
# 231  231         support-dobj
# 232  232         support-pobj_prep.by
# 233  233         surround-dobj
# 234  234         take-dobj
# 235  235         talk-pobj_prep.to
# 236  236         tell-dobj
# 237  237         test-dobj
# 238  238         thank-dobj
# 239  239         think-pobj_prep.about
# 240  240         treat-dobj
# 241  241         treat-pobj_prep.with
# 242  242         turn-dobj
# 243  243         understand-dobj
# 244  244         use-dobj
# 245  245         use-pobj_prep.by
# 246  246         use-pobj_prep.for
# 247  247         use-pobj_prep.in
# 248  248         use-pobj_prep.on
# 249  249         utilize-dobj
# 250  250         view-dobj
# 251  251         visit-dobj
# 252  252         wait-pobj_prep.for
# 253  253         want-dobj
# 254  254         wear-dobj
# 255  255         work-dobj
# 256  256         work-nsubj
# 257  257         work-pobj_prep.as
# 258  258         work-pobj_prep.in
# 259  259         work-pobj_prep.on
# 260  260         work-pobj_prep.with
# 261  261         write-dobj
# 262  262         write-pobj_prep.to
#
#                                                                                                                                                                               support nouns  \
# 0    ['person', 'people', 'student', 'family', 'child', 'patient', 'pupil', 'guest', 'vessel', 'passenger', 'crowd', 'ship', 'class', 'boy', 'friend', 'body']
# 1    ['goal', 'objective', 'balance', 'level', 'control', 'power', 'measure', 'life', 'target', 'security', 'form', 'equilibrium', 'system', 'action', 'justice', 'place']
# 2    ['drop', 'water', 'salt', 'sugar', 'weight', 'milk', 'line', 'column', 'ounce', 'material', 'alcohol', 'flour', 'juice', 'egg', 'piece', 'cup']
# 3    ['beauty', 'water', 'stock', 'collection', 'comfort', 'mixture', 'power', 'library', 'store', 'weight', 'life', 'fire', 'church', 'system', 'diet', 'soil']
# 4    ['people', 'house', 'assembly', 'envelope', 'crowd', 'man', 'court', 'person', 'king', 'chair', 'lady', 'officer', 'friend', 'woman', 'child', 'student']
# 5    ['power', 'head', 'heart', 'life', 'establishment', 'goal', 'target', 'control', 'objective', 'crown', 'point', 'style', 'person', 'man', 'throne', 'glory']
# 6    ['room', 'escape', 'movement', 'water', 'man', 'scope', 'person', 'formation', 'foot', 'place', 'weight', 'return', 'action', 'control', 'pound', 'power']
# 7    ['movement', 'meal', 'action', 'wear', 'rise', 'weight', 'escape', 'range', 'resistance', 'study', 'formation', 'support', 'return', 'case', 'extension', 'drop']
# 8    ['structure', 'case', 'system', 'material', 'record', 'form', 'circuit', 'mixture', 'action', 'source', 'movement', 'mechanism', 'gas', 'subject', 'light', 'market']
# 9    ['man', 'sign', 'book', 'sun', 'christ', 'star', 'light', 'form', 'enemy', 'head', 'line', 'face', 'woman', 'person', 'image', 'life']
# 10   ['surface', 'stage', 'side', 'face', 'earth', 'map', 'screen', 'record', 'subject', 'market', 'platform', 'street', 'deck', 'paper', 'sheet', 'roll']
# 11   ['material', 'people', 'body', 'collection', 'equipment', 'friend', 'machine', 'piece', 'officer', 'apparatus', 'set', 'general', 'representative', 'car', 'crowd', 'book']
# 12   ['class', 'person', 'place', 'man', 'individual', 'school', 'woman', 'area', 'station', 'office', 'case', 'post', 'teacher', 'officer', 'subject', 'family']
# 13   ['system', 'movement', 'people', 'life', 'form', 'father', 'formation', 'person', 'level', 'rock', 'school', 'man', 'structure', 'action', 'body', 'failure']
# 14   ['wall', 'side', 'surface', 'church', 'office', 'house', 'person', 'court', 'body', 'bone', 'shaft', 'school', 'base', 'frame', 'soil', 'head']
# 15   ['people', 'student', 'crowd', 'support', 'settler', 'iron', 'reader', 'insect', 'bird', 'tourist', 'worker', 'fish', 'body', 'class', 'woman', 'man']
# 16   ['contact', 'action', 'formation', 'subject', 'failure', 'shock', 'place', 'fire', 'food', 'crowd', 'enemy', 'movement', 'form', 'entanglement', 'rock', 'hazard']
# 17   ['weight', 'book', 'power', 'body', 'bridge', 'scale', 'system', 'diet', 'side', 'line', 'resistance', 'action', 'head', 'column', 'basket', 'ledger']
# 18   ['study', 'system', 'material', 'model', 'ground', 'record', 'source', 'story', 'life', 'case', 'weight', 'foundation', 'power', 'form', 'rule', 'formula']
# 39   ['house', 'place', 'point', 'throne', 'hand', 'life', 'power', 'door', 'light', 'surface', 'school', 'city', 'stop', 'church', 'ear', 'room']
# 40   ['power', 'hand', 'wife', 'enemy', 'father', 'face', 'family', 'cloud', 'story', 'friend', 'horse', 'heart', 'bottle', 'man', 'step', 'ship']
# 41   ['people', 'friend', 'world', 'room', 'person', 'chamber', 'vein', 'vessel', 'tube', 'apartment', 'family', 'surface', 'ocean', 'shore', 'church', 'man']
# 42   ['fig', 'system', 'weight', 'form', 'case', 'power', 'line', 'table', 'action', 'structure', 'set', 'record', 'area', 'life', 'level', 'date']
# 43   ['control', 'system', 'area', 'child', 'case', 'form', 'man', 'animal', 'power', 'level', 'woman', 'water', 'life', 'glory', 'sun', 'people']
# 44   ['course', 'study', 'cycle', 'circuit', 'school', 'circle', 'system', 'ruin', 'building', 'grade', 'story', 'book', 'line', 'set', 'form', 'record']
# 45   ['area', 'weight', 'table', 'power', 'measure', 'resistance', 'proportion', 'return', 'root', 'point', 'diameter', 'balance', 'date', 'matrix', 'level', 'set']
# 46   ['world', 'people', 'man', 'enemy', 'teacher', 'student', 'church', 'school', 'mankind', 'child', 'person', 'individual', 'worker', 'woman', 'witness', 'power']
# 47   ['point', 'link', 'rod', 'line', 'city', 'place', 'center', 'wire', 'cell', 'plate', 'shaft', 'system', 'tube', 'pole', 'body', 'water']
# 48   ['line', 'circuit', 'source', 'system', 'earth', 'battery', 'shaft', 'pump', 'galvanometer', 'side', 'tube', 'pole', 'generator', 'plate', 'pipe', 'wire']
# 49   ['person', 'cell', 'layer', 'piece', 'line', 'house', 'representative', 'mixture', 'plate', 'room', 'tube', 'officer', 'material', 'ship', 'body', 'row']
# 50   ['system', 'building', 'road', 'model', 'line', 'bridge', 'table', 'machine', 'house', 'map', 'triangle', 'scale', 'plant', 'dam', 'instrument', 'wall']
# 51   ['water', 'proportion', 'inhabitant', 'material', 'cell', 'salt', 'seed', 'nucleus', 'grain', 'iron', 'body', 'blood', 'line', 'room', 'egg', 'mixture']
# 52   ['action', 'movement', 'life', 'power', 'system', 'market', 'world', 'pest', 'level', 'course', 'body', 'insect', 'people', 'water', 'area', 'school']
# 53   ['model', 'book', 'style', 'form', 'document', 'paper', 'line', 'master', 'life', 'system', 'record', 'material', 'piece', 'print', 'map', 'ancient']
# 54   ['area', 'face', 'surface', 'range', 'ground', 'field', 'retreat', 'head', 'body', 'case', 'wall', 'subject', 'point', 'side', 'floor', 'earth']
# 55   ['whip', 'nut', 'shell', 'head', 'bone', 'heel', 'ice', 'joint', 'glass', 'finger', 'wall', 'bottle', 'egg', 'corn', 'lip', 'seed']
# 56   ['world', 'system', 'man', 'form', 'earl', 'power', 'image', 'market', 'peer', 'class', 'life', 'office', 'institution', 'board', 'alarm', 'body']
# 57   ['man', 'system', 'people', 'power', 'action', 'instrument', 'movement', 'authority', 'dam', 'hand', 'bank', 'person', 'bill', 'father', 'failure', 'christ']
# 58   ['image', 'place', 'world', 'heart', 'course', 'form', 'case', 'city', 'man', 'area', 'line', 'life', 'child', 'connection', 'soul', 'system']
# 59   ['subject', 'case', 'people', 'child', 'life', 'material', 'man', 'person', 'system', 'class', 'world', 'form', 'individual', 'enemy', 'point', 'patient']
# 60   ['power', 'area', 'line', 'scope', 'class', 'point', 'objective', 'system', 'form', 'goal', 'field', 'structure', 'place', 'set', 'man', 'life']
# 61   ['line', 'rule', 'formula', 'court', 'point', 'system', 'bureau', 'set', 'fig', 'authority', 'author', 'church', 'furrow', 'board', 'intersection', 'table']
# 62   ['soul', 'course', 'paper', 'fire', 'people', 'arm', 'city', 'child', 'power', 'man', 'key', 'baby', 'mail', 'water', 'milk', 'book']
# 63   ['power', 'authority', 'formula', 'support', 'comfort', 'form', 'light', 'rule', 'material', 'life', 'measure', 'descent', 'set', 'system', 'source', 'food']
# 64   ['source', 'study', 'cell', 'rock', 'root', 'system', 'book', 'form', 'animal', 'plant', 'people', 'ancestor', 'material', 'food', 'blood', 'authority']
# 65   ['system', 'life', 'form', 'circle', 'action', 'structure', 'person', 'place', 'case', 'man', 'beauty', 'movement', 'course', 'arc', 'people', 'world']
# 66   ['system', 'building', 'structure', 'machine', 'house', 'circuit', 'plant', 'equipment', 'form', 'engine', 'bridge', 'beam', 'costume', 'model', 'study', 'set']
# 67   ['student', 'child', 'school', 'people', 'study', 'reader', 'teacher', 'class', 'reception', 'person', 'pupil', 'ministry', 'control', 'church', 'market', 'comfort']
# 68   ['sign', 'movement', 'point', 'case', 'wave', 'source', 'carrier', 'form', 'line', 'leak', 'ray', 'spot', 'person', 'man', 'light', 'enemy']
# 69   ['system', 'power', 'habit', 'form', 'personality', 'life', 'style', 'structure', 'market', 'area', 'model', 'art', 'line', 'body', 'material', 'point']
# 70   ['power', 'sign', 'flag', 'beauty', 'banner', 'form', 'arm', 'structure', 'glory', 'art', 'row', 'line', 'material', 'face', 'style', 'collection']
# 71   ['window', 'form', 'construction', 'case', 'fig', 'action', 'light', 'life', 'field', 'table', 'place', 'room', 'book', 'structure', 'shop', 'course']
# 72   ['justice', 'action', 'office', 'bit', 'piece', 'life', 'child', 'people', 'study', 'return', 'man', 'hair', 'washing', 'boy', 'book', 'rise']
# 73   ['foot', 'body', 'leg', 'boat', 'chain', 'man', 'anchor', 'cart', 'gun', 'canoe', 'sledge', 'cannon', 'child', 'life', 'woman', 'chair']
# 74   ['bank', 'paper', 'side', 'glove', 'map', 'scale', 'surface', 'ground', 'beach', 'wood', 'shore', 'board', 'source', 'reserve', 'blackboard', 'line']
# 75   ['car', 'enemy', 'horse', 'home', 'cattle', 'nail', 'wheel', 'automobile', 'machine', 'man', 'machinery', 'people', 'pump', 'wedge', 'pile', 'generator']
# 76   ['bomb', 'subject', 'anchor', 'hand', 'head', 'line', 'arm', 'curtain', 'stone', 'gun', 'foot', 'seed', 'handkerchief', 'piece', 'book', 'rein']
# 77   ['food', 'bread', 'meat', 'dinner', 'meal', 'fruit', 'breakfast', 'supper', 'fish', 'lunch', 'grass', 'apple', 'egg', 'beef', 'heart', 'piece']
# 117  ['system', 'life', 'school', 'road', 'power', 'soil', 'nutrition', 'style', 'stock', 'habit', 'resistance', 'structure', 'art', 'level', 'race', 'balance']
# 118  ['case', 'area', 'person', 'form', 'material', 'study', 'representative', 'people', 'child', 'subject', 'range', 'class', 'city', 'power', 'woman', 'point']
# 119  ['woman', 'child', 'man', 'case', 'officer', 'area', 'form', 'material', 'school', 'city', 'person', 'weight', 'representative', 'book', 'line', 'plate']
# 120  ['bank', 'city', 'material', 'college', 'system', 'church', 'institution', 'school', 'device', 'university', 'body', 'form', 'club', 'rule', 'president', 'control']
# 121  ['power', 'resistance', 'area', 'weight', 'stock', 'proportion', 'range', 'level', 'surface', 'action', 'comfort', 'diameter', 'life', 'return', 'store', 'authority']
# 122  ['action', 'field', 'ray', 'light', 'movement', 'alcohol', 'diet', 'shock', 'habit', 'contact', 'wave', 'system', 'threat', 'food', 'wind', 'rise']
# 123  ['reader', 'king', 'people', 'house', 'world', 'friend', 'master', 'father', 'authority', 'emperor', 'court', 'patient', 'mother', 'officer', 'minister', 'student']
# 124  ['action', 'movement', 'measure', 'study', 'system', 'cycle', 'bill', 'formation', 'step', 'chain', 'contact', 'sequence', 'course', 'form', 'structure', 'line']
# 125  ['tube', 'needle', 'piece', 'resistance', 'plug', 'finger', 'key', 'stopper', 'point', 'line', 'pin', 'catheter', 'date', 'wire', 'plate', 'comma']
# 126  ['system', 'equipment', 'plant', 'machinery', 'machine', 'pump', 'engine', 'apparatus', 'light', 'device', 'line', 'officer', 'pipe', 'motor', 'tank', 'set']
# 127  ['system', 'equipment', 'plant', 'machinery', 'machine', 'device', 'pump', 'apparatus', 'line', 'engine', 'set', 'light', 'meter', 'telephone', 'tank', 'pipe']
# 128  ['bill', 'system', 'subject', 'measure', 'form', 'friend', 'material', 'speaker', 'study', 'machinery', 'finger', 'person', 'catheter', 'reader', 'rule', 'art']
# 129  ['security', 'stock', 'bond', 'plant', 'equipment', 'building', 'bank', 'machinery', 'form', 'house', 'construction', 'factory', 'machine', 'mill', 'line', 'system']
# 130  ['system', 'people', 'area', 'action', 'power', 'person', 'movement', 'structure', 'life', 'child', 'formation', 'point', 'study', 'bone', 'construction', 'body']
# 131  ['case', 'study', 'action', 'formation', 'system', 'movement', 'construction', 'ruin', 'life', 'control', 'suit', 'form', 'fight', 'subject', 'structure', 'course']
# 132  ['man', 'people', 'animal', 'child', 'bird', 'father', 'person', 'enemy', 'king', 'deer', 'game', 'woman', 'wife', 'horse', 'brother', 'dog']
# 133  ['system', 'house', 'man', 'school', 'bill', 'church', 'hill', 'line', 'author', 'point', 'hall', 'cell', 'college', 'book', 'movement', 'board']
# 134  ['boat', 'ship', 'movement', 'satellite', 'canoe', 'drive', 'missile', 'torpedo', 'vessel', 'site', 'rocket', 'plane', 'arrow', 'bark', 'magazine', 'paper']
# 135  ['art', 'rule', 'tongue', 'habit', 'story', 'material', 'subject', 'craft', 'game', 'maze', 'form', 'system', 'table', 'set', 'control', 'line']
# 136  ['room', 'house', 'school', 'place', 'home', 'city', 'child', 'son', 'college', 'world', 'office', 'church', 'wife', 'subject', 'body', 'ship']
# 137  ['arm', 'coil', 'city', 'circuit', 'area', 'system', 'hand', 'chain', 'man', 'world', 'people', 'life', 'line', 'heart', 'point', 'centre']
# 138  ['book', 'material', 'source', 'point', 'step', 'subject', 'case', 'person', 'stock', 'people', 'course', 'area', 'form', 'security', 'objective', 'place']
# 139  ['gun', 'ship', 'car', 'rifle', 'boat', 'piece', 'wagon', 'cart', 'musket', 'horse', 'pistol', 'vessel', 'truck', 'camel', 'mule', 'memory']
# 140  ['point', 'source', 'place', 'line', 'center', 'site', 'material', 'area', 'seat', 'spot', 'plant', 'city', 'body', 'school', 'station', 'book']
# 141  ['city', 'area', 'center', 'place', 'building', 'valley', 'room', 'heart', 'corner', 'field', 'wall', 'basement', 'plane', 'centre', 'head', 'house']
# 142  ['side', 'street', 'bank', 'floor', 'line', 'surface', 'site', 'ground', 'corner', 'top', 'coast', 'shore', 'map', 'hill', 'road', 'slope']
# 143  ['watch', 'face', 'man', 'sky', 'window', 'map', 'book', 'house', 'hand', 'life', 'world', 'star', 'clock', 'side', 'woman', 'girl']
# 144  ['place', 'help', 'man', 'sign', 'support', 'food', 'world', 'house', 'wife', 'source', 'friend', 'water', 'spot', 'lodging', 'book', 'site']
# 145  ['balance', 'level', 'system', 'contact', 'equilibrium', 'control', 'school', 'action', 'life', 'authority', 'power', 'ground', 'family', 'record', 'reserve', 'place']
# 146  ['study', 'acquaintance', 'friend', 'room', 'man', 'escape', 'point', 'sign', 'home', 'return', 'contact', 'fire', 'rule', 'life', 'movement', 'appointment']
# 147  ['horse', 'editor', 'house', 'boat', 'school', 'people', 'child', 'life', 'case', 'system', 'home', 'institution', 'director', 'ship', 'store', 'factory']
# 148  ['material', 'people', 'market', 'instrument', 'control', 'system', 'machine', 'tool', 'machinery', 'lever', 'world', 'string', 'apparatus', 'form', 'valve', 'stock']
# 149  ['dress', 'power', 'hair', 'line', 'wall', 'mountain', 'shade', 'face', 'piece', 'set', 'coat', 'level', 'furniture', 'factory', 'gown', 'suit']
# 150  ['action', 'system', 'form', 'structure', 'course', 'rule', 'subject', 'power', 'institution', 'life', 'habit', 'surface', 'formula', 'movement', 'style', 'bill']
# 151  ['head', 'hand', 'body', 'arm', 'heart', 'world', 'step', 'lip', 'foot', 'finger', 'mountain', 'leg', 'point', 'people', 'stone', 'water']
# 152  ['place', 'side', 'city', 'door', 'area', 'house', 'action', 'point', 'site', 'window', 'home', 'level', 'room', 'street', 'table', 'center']
# 153  ['help', 'support', 'food', 'study', 'man', 'friend', 'water', 'hand', 'light', 'drink', 'room', 'power', 'glass', 'place', 'comfort', 'control']
# 154  ['child', 'baby', 'mother', 'home', 'patient', 'father', 'woman', 'school', 'leg', 'soldier', 'sister', 'hand', 'foot', 'student', 'case', 'babe']
# 155  ['case', 'animal', 'patient', 'connection', 'study', 'child', 'place', 'man', 'course', 'life', 'form', 'cell', 'system', 'field', 'person', 'church']
# 156  ['resistance', 'prayer', 'hand', 'course', 'help', 'prospect', 'arm', 'food', 'crown', 'place', 'life', 'support', 'seat', 'post', 'security', 'field']
# 157  ['school', 'college', 'university', 'king', 'institution', 'system', 'bank', 'city', 'people', 'friend', 'christ', 'man', 'employer', 'church', 'person', 'author']
# 158  ['door', 'mouth', 'gate', 'fire', 'window', 'book', 'school', 'heart', 'box', 'lip', 'valve', 'store', 'field', 'shop', 'office', 'road']
# 159  ['machine', 'system', 'plant', 'valve', 'line', 'store', 'equipment', 'school', 'mill', 'machinery', 'pump', 'relay', 'station', 'car', 'switch', 'mechanism']
# 160  ['system', 'measure', 'form', 'action', 'rule', 'extension', 'bill', 'power', 'movement', 'life', 'church', 'school', 'authority', 'man', 'world', 'enemy']
# 161  ['house', 'home', 'stock', 'horse', 'car', 'place', 'store', 'ship', 'building', 'mill', 'automobile', 'factory', 'book', 'dog', 'boat', 'shop']
# 162  ['life', 'study', 'movement', 'action', 'game', 'sport', 'formation', 'system', 'form', 'fight', 'athletics', 'assembly', 'power', 'course', 'primary', 'control']
# 163  ['office', 'action', 'movement', 'step', 'piece', 'prayer', 'surgery', 'study', 'stunt', 'circuit', 'cycle', 'toilet', 'sequence', 'set', 'opera', 'range']
# 164  ['flower', 'piece', 'book', 'stone', 'hat', 'thread', 'paper', 'cotton', 'fruit', 'berry', 'bit', 'stick', 'man', 'bone', 'bag', 'receiver']
# 165  ['table', 'side', 'throne', 'top', 'ground', 'head', 'record', 'surface', 'level', 'floor', 'board', 'market', 'back', 'line', 'shelf', 'plate']
# 166  ['game', 'card', 'piano', 'instrument', 'ball', 'tennis', 'golf', 'violin', 'fool', 'football', 'flute', 'bridge', 'fiddle', 'baseball', 'man', 'guitar']
# 167  ['course', 'failure', 'action', 'return', 'level', 'ruin', 'fall', 'movement', 'form', 'grade', 'date', 'life', 'structure', 'point', 'rise', 'weight']
# 168  ['hand', 'button', 'lip', 'point', 'key', 'lever', 'suit', 'trigger', 'face', 'arm', 'finger', 'head', 'bar', 'case', 'kiss', 'spring']
# 169  ['fruit', 'book', 'food', 'form', 'material', 'movement', 'action', 'flower', 'light', 'image', 'child', 'seed', 'power', 'line', 'surface', 'field']
# 170  ['action', 'cell', 'ray', 'plant', 'system', 'light', 'movement', 'body', 'field', 'machine', 'contact', 'wave', 'animal', 'source', 'instrument', 'power']
# 171  ['study', 'glory', 'formation', 'comfort', 'action', 'life', 'movement', 'measure', 'establishment', 'art', 'justice', 'spread', 'system', 'security', 'habit', 'objective']
# 172  ['life', 'people', 'child', 'person', 'citizen', 'body', 'woman', 'city', 'individual', 'subject', 'worker', 'family', 'surface', 'man', 'line', 'head']
# 173  ['food', 'material', 'support', 'place', 'system', 'source', 'accommodation', 'foundation', 'measure', 'background', 'framework', 'school', 'security', 'power', 'base', 'substitute']
# 174  ['house', 'school', 'system', 'man', 'bill', 'study', 'father', 'rule', 'book', 'city', 'church', 'family', 'world', 'mother', 'assembly', 'teacher']
# 175  ['school', 'rule', 'system', 'authority', 'board', 'bank', 'institution', 'employer', 'city', 'office', 'bill', 'college', 'study', 'teacher', 'university', 'church']
# 176  ['trigger', 'string', 'hair', 'house', 'leg', 'hat', 'curtain', 'rope', 'door', 'cord', 'chair', 'face', 'lever', 'boot', 'wire', 'watch']
# 177  ['stock', 'book', 'material', 'food', 'house', 'power', 'equipment', 'horse', 'security', 'bond', 'arm', 'home', 'site', 'machine', 'life', 'machinery']
# 178  ['course', 'study', 'subject', 'line', 'enemy', 'goal', 'measure', 'route', 'objective', 'life', 'system', 'train', 'game', 'road', 'track', 'point']
# 179  ['place', 'hand', 'form', 'prison', 'mouth', 'power', 'box', 'jail', 'iron', 'light', 'water', 'bag', 'room', 'book', 'chain', 'case']
# 180  ['hat', 'clothes', 'table', 'paper', 'board', 'guard', 'record', 'dress', 'coat', 'market', 'head', 'side', 'shoe', 'cap', 'level', 'gown']
# 181  ['book', 'support', 'table', 'connection', 'life', 'paper', 'gazette', 'press', 'place', 'case', 'newspaper', 'market', 'chap', 'record', 'register', 'magazine']
# 182  ['foot', 'pound', 'meter', 'point', 'form', 'high', 'cycle', 'grain', 'level', 'ounce', 'person', 'yard', 'violet', 'orange', 'man', 'diameter']
# 183  ['hat', 'bottle', 'hand', 'gun', 'glass', 'book', 'telephone', 'rifle', 'coat', 'star', 'paper', 'phone', 'pipe', 'pistol', 'revolver', 'box']
# 184  ['book', 'paper', 'story', 'newspaper', 'line', 'material', 'prayer', 'life', 'sign', 'record', 'author', 'magazine', 'document', 'heart', 'print', 'room']
# ...
# 141  ['mall', 'computer', 'bar', 'sequence', 'folder', 'menu', 'paper', 'mansion', 'matrix', 'module']
# 142  ['server', 'web', 'chain', 'network', 'tab', 'internet', 'computer', 'menu', 'node', 'cell']
# 143  ['computer', 'marker', 'video', 'tab', 'website', 'artifact', 'viewer', 'intersection', 'constraint', 'interface']
# 144  ['motel', 'server', 'niche', 'node', 'study', 'network', 'snack', 'phone', 'framework', 'anomaly']
# 145  ['fiber', 'web', 'filling', 'repository', 'website', 'server', 'peg', 'cache', 'hardware', 'veneer']
# 146  ['semiconductor', 'constraint', 'birdie', 'videotape', 'server', 'humankind', 'widget', 'internet', 'tofu', 'video']
# 147  ['threat', 'connection', 'server', 'base', 'site', 'interface', 'memory', 'document', 'user', 'storage']
# 148  ['base', 'memory', 'array', 'bit', 'collection', 'tree', 'woman', 'embryo', 'date', 'range']
# 149  ['node', 'hatch', 'file', 'rule', 'row', 'constraint', 'pant', 'market', 'lipstick', 'heel']
# 150  ['block', 'constraint', 'key', 'package', 'menu', 'array', 'interface', 'site', 'register', 'display']
# 151  ['rat', 'grating', 'packet', 'folder', 'filter', 'robot', 'recipient', 'clip', 'node', 'cheese']
# 152  ['record', 'target', 'file', 'slide', 'server', 'couch', 'model', 'layer', 'node', 'folder']
# 153  ['sitter', 'refresher', 'wheelchair', 'date', 'appointment', 'server', 'brace', 'phone', 'print', 'taxi']
# 154  ['mug', 'theorist', 'support', 'goal', 'employee', 'model', 'setting', 'system', 'round', 'cow']
# 155  ['source', 'detector', 'volunteer', 'primate', 'recipient', 'device', 'rodent', 'ref', 'matrix', 'assemblage']
# 156  ['storage', 'video', 'carrot', 'interface', 'user', 'call', 'file', 'cue', 'surgery', 'transport']
# 157  ['brand', 'package', 'web', 'framework', 'server', 'architecture', 'platform', 'interface', 'internet', 'developer']
# 158  ['editor', 'palette', 'tab', 'picker', 'fridge', 'manager', 'image', 'console', 'drape', 'freezer']
# 159  ['server', 'interface', 'support', 'landfill', 'robot', 'housing', 'laser', 'mouse', 'hardware', 'platform']
# 160  ['server', 'block', 'link', 'bit', 'network', 'chain', 'physician', 'interface', 'file', 'target']
# 161  ['network', 'file', 'phone', 'portfolio', 'center', 'handgun', 'nightclub', 'salon', 'microcomputer', 'lock']
# 162  ['room', 'chat', 'classroom', 'binding', 'marketplace', 'emu', 'model', 'screening', 'set', 'book']
# 163  ['replacement', 'setup', 'center', 'school', 'sweep', 'aggregation', 'upgrade', 'bypass', 'switch', 'screen']
# 164  ['marker', 'pant', 'college', 'device', 'door', 'outfit', 'pizza', 'control', 'van', 'backpack']
# 165  ['grill', 'web', 'ventilator', 'hold', 'employee', 'desktop', 'server', 'internet', 'bus', 'network']
# 166  ['slot', 'file', 'video', 'cassette', 'frame', 'medium', 'clip', 'gig', 'dress', 'bond']
# 167  ['support', 'target', 'balance', 'span', 'patient', 'style', 'transport', 'source', 'conformation', 'scale']
# 168  ['arrow', 'sign', 'pump', 'escape', 'tab', 'area', 'jean', 'sequence', 'screen', 'shift']
# 169  ['mediator', 'crate', 'probe', 'video', 'videotape', 'laser', 'kit', 'wafer', 'cultivar', 'camp']
# 170  ['programmer', 'module', 'package', 'journalist', 'monitor', 'agonist', 'neutrophil', 'synthesizer', 'vendor', 'talker']
# 171  ['base', 'framework', 'car', 'cell', 'binding', 'author', 'manager', 'linkage', 'mechanic', 'network']
# 172  ['mammal', 'shoreline', 'ocean', 'journalist', 'farmland', 'computer', 'owl', 'key', 'dolphin', 'turtle']
# 173  ['binding', 'organizer', 'server', 'video', 'telecommunication', 'processor', 'handler', 'module', 'blockade', 'probe']
# 174  ['website', 'user', 'server', 'image', 'site', 'framework', 'internet', 'network', 'vendor', 'interface']
# 175  ['server', 'internet', 'developer', 'package', 'hardware', 'interface', 'module', 'container', 'processor', 'pharmacist']
# 176  ['shotgun', 'phone', 'menu', 'handgun', 'recorder', 'cock', 'vial', 'beer', 'container', 'comforter']
# 177  ['level', 'puppy', 'apartment', 'drive', 'monitor', 'player', 'television', 'call', 'server', 'handgun']
# 178  ['balance', 'tie', 'office', 'contact', 'control', 'weapon', 'market', 'defense', 'major', 'link']
# 179  ['fridge', 'player', 'dryer', 'wheelchair', 'binder', 'backpack', 'processor', 'dishwasher', 'microwave', 'tape']
# 180  ['grill', 'internet', 'bra', 'burner', 'web', 'stereo', 'ventilator', 'speaker', 'tv', 'hold']
# 181  ['woman', 'collins', 'ball', 'wolf', 'griffin', 'medium', 'porter', 'reed', 'murphy', 'gate']
# 182  ['urn', 'site', 'mainframe', 'supercomputer', 'surgery', 'network', 'micrometer', 'hotel', 'security', 'restaurant']
# 183  ['glory', 'baby', 'zipper', 'file', 'face', 'mouse', 'jean', 'tea', 'napkin', 'radio']
# 184  ['rainbow', 'tv', 'ingredient', 'aura', 'rock', 'disc', 'race', 'site', 'port', 'header']
# 185  ['plaque', 'memory', 'binding', 'pathogen', 'wrinkle', 'overall', 'alarm', 'alcohol', 'litter', 'cramp']
# 186  ['black', 'ref', 'website', 'cover', 'server', 'user', 'mediator', 'constraint', 'interface', 'package']
# 187  ['site', 'linkage', 'threat', 'race', 'makeup', 'transport', 'array', 'root', 'network', 'black']
# 188  ['hardware', 'packaging', 'portfolio', 'fetus', 'wright', 'sponsor', 'internet', 'artifact', 'rape', 'interface']
# 189  ['kid', 'screening', 'interface', 'implant', 'catheter', 'server', 'module', 'portfolio', 'internet', 'linkage']
# 190  ['agonist', 'model', 'site', 'bit', 'mouth', 'constraint', 'call', 'mediator', 'level', 'file']
# 191  ['camouflage', 'server', 'computer', 'internet', 'television', 'mixture', 'reserve', 'level', 'link', 'formation']
# 192  ['bra', 'artifact', 'user', 'tattoo', 'panty', 'fastener', 'sequence', 'module', 'hardware', 'pathogen']
# 193  ['catheter', 'chip', 'call', 'handset', 'marshall', 'server', 'missile', 'hardware', 'computer', 'token']
# 194  ['computer', 'stakeholder', 'tag', 'printer', 'portfolio', 'server', 'pointer', 'folder', 'controller', 'module']
# 195  ['control', 'packet', 'table', 'connection', 'library', 'raise', 'file', 'user', 'system', 'designer']
# 196  ['wheelchair', 'pacemaker', 'taxi', 'bypass', 'interface', 'processor', 'upgrade', 'header', 'server', 'programmer']
# 197  ['interface', 'module', 'layer', 'package', 'file', 'server', 'architecture', 'regulator', 'framework', 'developer']
# 198  ['folder', 'network', 'site', 'marrow', 'shelter', 'storage', 'setting', 'computer', 'file', 'node']
# 199  ['screen', 'decline', 'user', 'mail', 'objective', 'target', 'array', 'constraint', 'collection', 'medium']
# 200  ['framework', 'wine', 'interface', 'swing', 'site', 'caput', 'file', 'link', 'constraint', 'artifact']
# 201  ['array', 'collection', 'row', 'column', 'root', 'date', 'sequence', 'structure', 'phone', 'node']
# 202  ['server', 'menu', 'motel', 'desktop', 'panel', 'tab', 'display', 'campsite', 'console', 'computer']
# 203  ['panel', 'scale', 'menu', 'clothing', 'calf', 'panty', 'button', 'plane', 'swell', 'bra']
# 204  ['site', 'server', 'shelter', 'buffer', 'tab', 'suite', 'setup', 'manager', 'filter', 'package']
# 205  ['host', 'window', 'device', 'port', 'network', 'processor', 'hardware', 'workstation', 'node', 'microcomputer']
# 206  ['turtle', 'map', 'buffer', 'bay', 'butt', 'humankind', 'setting', 'guy', 'owl', 'tiger']
# 207  ['port', 'slide', 'probe', 'network', 'print', 'display', 'plane', 'source', 'string', 'laser']
# 208  ['engine', 'internet', 'purse', 'computer', 'string', 'drive', 'web', 'sequence', 'network', 'image']
# 209  ['artifact', 'framework', 'killer', 'shoe', 'marker', 'table', 'sequence', 'housing', 'user', 'node']
# 210  ['interface', 'server', 'video', 'flop', 'website', 'laser', 'internet', 'screening', 'module', 'videotape']
# 211  ['deviant', 'site', 'essence', 'barrier', 'equal', 'player', 'indicator', 'substitute', 'medium', 'actor']
# 212  ['tab', 'folder', 'user', 'module', 'clip', 'tag', 'server', 'open', 'font', 'interface']
# 213  ['artifact', 'array', 'author', 'crack', 'housing', 'video', 'widget', 'missile', 'subsidiary', 'jean']
# 214  ['port', 'astronaut', 'transmission', 'fax', 'slide', 'human', 'header', 'tape', 'video', 'athlete']
# 215  ['fax', 'node', 'router', 'sender', 'host', 'computer', 'receiver', 'server', 'device', 'user']
# 216  ['landfill', 'window', 'node', 'memory', 'module', 'monitor', 'network', 'processor', 'screen', 'display']
# 217  ['burger', 'stint', 'recipient', 'ingredient', 'file', 'tablespoon', 'humankind', 'niche', 'onion', 'pizza']
# 218  ['interface', 'phone', 'header', 'font', 'website', 'tab', 'menu', 'folder', 'user', 'server']
# 219  ['medium', 'connection', 'document', 'network', 'printer', 'file', 'key', 'needle', 'folder', 'model']
# 220  ['twin', 'computer', 'thread', 'processor', 'case', 'theorist', 'player', 'sibling', 'sender', 'device']
# 221  ['video', 'helicopter', 'weight', 'hoop', 'blank', 'image', 'student', 'episode', 'outdoors', 'airliner']
# 222  ['loser', 'palette', 'menu', 'video', 'tan', 'tab', 'folder', 'dad', 'module', 'videotape']
# 223  ['site', 'tv', 'car', 'server', 'network', 'recorder', 'briefcase', 'computer', 'newspaper', 'television']
# 224  ['row', 'disk', 'set', 'frame', 'sequence', 'layer', 'block', 'network', 'scale', 'stage']
# 225  ['drive', 'user', 'file', 'server', 'key', 'host', 'font', 'string', 'interface', 'folder']
# 226  ['site', 'manager', 'tool', 'document', 'server', 'fieldwork', 'van', 'window', 'bike', 'editor']
# 227  ['setting', 'server', 'document', 'root', 'site', 'map', 'file', 'contact', 'frame', 'window']
# 228  ['killer', 'date', 'guy', 'diet', 'rape', 'rose', 'server', 'thread', 'bastard', 'dam']
# 229  ['point', 'packet', 'model', 'key', 'structure', 'row', 'setting', 'date', 'pointer', 'video']
# 230  ['ram', 'folder', 'module', 'server', 'matrix', 'string', 'node', 'map', 'document', 'model']
# 231  ['interface', 'module', 'linkage', 'reader', 'automation', 'entrepreneur', 'java', 'storage', 'processor', 'server']
# 232  ['model', 'server', 'interface', 'architecture', 'implant', 'computer', 'hardware', 'driver', 'window', 'vendor']
# 233  ['prosthesis', 'rape', 'internet', 'plaque', 'sequence', 'surgery', 'launch', 'stadium', 'sport', 'computer']
# 234  ['node', 'video', 'module', 'user', 'missile', 'blindfold', 'array', 'polygraph', 'niacin', 'ramp']
# 235  ['plant', 'set', 'fan', 'server', 'speaker', 'user', 'ray', 'vendor', 'bobby', 'local']
# 236  ['window', 'router', 'microprocessor', 'processor', 'dispatcher', 'flash', 'buddy', 'hardware', 'sender', 'server']
# 237  ['button', 'server', 'constraint', 'fetus', 'file', 'chip', 'module', 'setup', 'interface', 'flag']
# 238  ['employee', 'resident', 'holder', 'referee', 'guy', 'support', 'sponsor', 'young', 'centre', 'organizer']
# 239  ['dad', 'level', 'computer', 'elephant', 'mess', 'medium', 'film', 'memory', 'link', 'weapon']
# 240  ['wrinkle', 'herpes', 'flash', 'gad', 'kid', 'louse', 'user', 'juvenile', 'athlete', 'fetus']
# 241  ['medium', 'laser', 'device', 'vehicle', 'pa', 'system', 'replacement', 'plate', 'agonist', 'appliance']
# 242  ['monitor', 'ocean', 'stereo', 'computer', 'center', 'display', 'phone', 'negative', 'entrepreneur', 'tape']
# 243  ['interface', 'internet', 'user', 'intersection', 'marketplace', 'file', 'driver', 'cue', 'block', 'matrix']
# 244  ['video', 'cache', 'automaton', 'pet', 'sunscreen', 'workstation', 'user', 'microprocessor', 'java', 'microcomputer']
# 245  ['module', 'internet', 'layer', 'package', 'tool', 'mail', 'router', 'server', 'site', 'window']
# 246  ['bypass', 'laser', 'array', 'interface', 'user', 'composite', 'packet', 'server', 'video', 'failure']
# 247  ['microcomputer', 'interface', 'kit', 'server', 'video', 'internet', 'modem', 'robot', 'implant', 'chip']
# 248  ['link', 'citizen', 'server', 'channel', 'microcomputer', 'interface', 'file', 'internet', 'twin', 'web']
# 249  ['link', 'panel', 'implant', 'architecture', 'marker', 'interface', 'package', 'processor', 'internet', 'laser']
# 250  ['style', 'monitor', 'folder', 'video', 'overall', 'palette', 'clip', 'menu', 'videotape', 'panel']
# 251  ['setting', 'appointment', 'node', 'feeder', 'supermarket', 'mall', 'link', 'winery', 'restroom', 'channel']
# 252  ['disk', 'thread', 'screen', 'computer', 'waitress', 'token', 'file', 'organ', 'threat', 'server']
# 253  ['server', 'poster', 'bar', 'clip', 'user', 'computer', 'quilt', 'puppy', 'rainbow', 'hamburger']
# 254  ['sunscreen', 'monitor', 'pacemaker', 'cologne', 'microphone', 'backpack', 'tattoo', 'boxer', 'camouflage', 'contact']
# 255  ['desk', 'computer', 'mate', 'phone', 'butt', 'file', 'tail', 'link', 'button', 'beat']
# 256  ['network', 'link', 'internet', 'card', 'diet', 'server', 'library', 'button', 'user', 'filter']
# 257  ['midwife', 'trainer', 'vendor', 'hostess', 'coach', 'hairdresser', 'attorney', 'advocate', 'programmer', 'nanny']
# 258  ['sport', 'video', 'authority', 'nightclub', 'patient', 'tv', 'document', 'complex', 'marketplace', 'site']
# 259  ['button', 'tan', 'layer', 'server', 'art', 'transmission', 'dinner', 'internet', 'motorcycle', 'bike']
# 260  ['video', 'hardware', 'interface', 'developer', 'server', 'site', 'elder', 'memory', 'date', 'style']
# 261  ['package', 'handler', 'extension', 'classroom', 'module', 'interface', 'driver', 'buffer', 'server', 'lock']
# 262  ['pipe', 'register', 'screen', 'console', 'medium', 'port', 'tape', 'buffer', 'drive', 'disk']

# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 1200)
noun_df = pd.read_csv('/h/19/jadeleiyu/frame_extension/data/gsn/noun_eval_df_{}s.csv'.format(1990))
noun_df
# Out:
# /h/19/jadeleiyu/frame_extension/frame_extension_venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#      Unnamed: 0    query noun  \
# 0    0           adenovirus
# 1    1           ant
# 2    2           apartment
# 3    3           area
# 4    4           asp
# 5    5           auditor
# 6    6           bank
# 7    7           bean
# 8    8           center
# 9    9           circle
# 10   10          city
# 11   11          clip
# 12   12          computer
# 13   13          console
# 14   14          construction
# 15   15          cooker
# 16   16          court
# 17   17          cue
# 18   18          dashboard
# 19   19          date
# 20   20          decline
# 21   21          designer
# 22   22          desktop
# 23   23          dial
# 24   24          doe
# 25   25          dough
# 26   26          face
# 27   27          flash
# 28   28          folder
# 29   29          frame
# 30   30          fret
# 31   31          gallery
# 32   32          game
# 33   33          gate
# 34   34          grandparent
# 35   35          grill
# 36   36          hack
# 37   37          hacker
# 38   38          hall
# 39   39          handler
# 40   40          hash
# 41   41          hat
# 42   42          help
# 43   43          high
# 44   44          hook
# 45   45          interface
# 46   46          kernel
# 47   47          key
# 48   48          knockout
# 49   49          layer
# 50   50          level
# 51   51          library
# 52   52          licorice
# 53   53          light
# 54   54          line
# 55   55          link
# 56   56          linkage
# 57   57          loft
# 58   58          mall
# 59   59          mixer
# 60   60          module
# 61   61          mountain
# 62   62          mouse
# 63   63          network
# 64   64          open
# 65   65          pack
# 66   66          palace
# 67   67          pentagon
# 68   68          phone
# 69   69          picker
# 70   70          platform
# 71   71          player
# 72   72          polygon
# 73   73          portal
# 74   74          reader
# 75   75          restaurant
# 76   76          return
# 77   77          roadblock
# 78   78          route
# 79   79          router
# 80   80          row
# 81   81          rule
# 82   82          safe
# 83   83          school
# 84   84          screen
# 85   85          security
# 86   86          seeker
# 87   87          sequence
# 88   88          server
# 89   89          setting
# 90   90          site
# 91   91          snap
# 92   92          socket
# 93   93          spline
# 94   94          stakeholder
# 95   95          studio
# 96   96          style
# 97   97          subject
# 98   98          tab
# 99   99          tag
# 100  100         tool
# 101  101         track
# 102  102         train
# 103  103         trigger
# 104  104         truck
# 105  105         user
# 106  106         video
# 107  107         viewer
# 108  108         wand
# 109  109         web
# 110  110         website
# 111  111         weight
# 112  112         wrapper
#
#                                                                                              ground truth extended frames
# 0    ['generate-dobj']
# 1    ['run-dobj']
# 2    ['exit-dobj']
# 3    ['configure-dobj']
# 4    ['create-dobj', 'provide-pobj_prep.by']
# 5    ['use-nsubj']
# 6    ['target-dobj']
# 7    ['access-dobj', 'manage-dobj']
# 8    ['click-dobj']
# 9    ['pull-dobj']
# 10   ['string-dobj']
# 11   ['add-pobj_prep.to', 'click-dobj', 'delete-dobj', 'export-dobj', 'have-nsubj', 'import-dobj', 'work-pobj_prep.with']
# 12   ['pull-dobj']
# 13   ['install-dobj', 'string-dobj']
# 14   ['rethink-dobj']
# 15   ['add-pobj_prep.to']
# 16   ['rethink-dobj']
# 17   ['add-pobj_prep.to']
# 18   ['create-dobj', 'use-dobj']
# 19   ['string-dobj']
# 20   ['rethink-dobj']
# 21   ['open-dobj']
# 22   ['add-pobj_prep.to', 'run-dobj']
# 23   ['hit-dobj']
# 24   ['run-dobj']
# 25   ['create-dobj', 'set-pobj_prep.to']
# 26   ['delete-dobj']
# 27   ['use-nsubj']
# 28   ['have-nsubj']
# 29   ['export-dobj', 'target-dobj']
# 30   ['use-dobj']
# 31   ['choose-dobj']
# 32   ['exit-dobj']
# 33   ['head-pobj_prep.to']
# 34   ['work-pobj_prep.with']
# 35   ['have-nsubj']
# 36   ['run-dobj']
# 37   ['use-nsubj']
# 38   ['head-pobj_prep.to']
# 39   ['add-pobj_prep.to', 'generate-dobj']
# 40   ['generate-dobj']
# 41   ['provide-pobj_prep.by']
# 42   ['open-dobj']
# 43   ['set-pobj_prep.to']
# 44   ['install-dobj']
# 45   ['open-dobj']
# 46   ['install-dobj']
# 47   ['export-dobj', 'import-dobj']
# 48   ['generate-dobj', 'use-dobj']
# 49   ['target-dobj']
# 50   ['configure-dobj']
# 51   ['instal-nsubj']
# 52   ['use-dobj']
# 53   ['set-pobj_prep.to']
# 54   ['rethink-dobj']
# 55   ['target-dobj']
# 56   ['choose-dobj']
# 57   ['create-dobj']
# 58   ['hit-dobj']
# 59   ['create-dobj']
# 60   ['manage-dobj']
# 61   ['head-pobj_prep.to']
# 62   ['configure-dobj']
# 63   ['click-dobj']
# 64   ['import-dobj']
# 65   ['instal-nsubj']
# 66   ['rethink-dobj']
# 67   ['hit-dobj']
# 68   ['open-dobj']
# 69   ['access-dobj']
# 70   ['target-dobj']
# 71   ['instal-nsubj']
# 72   ['choose-dobj']
# 73   ['provide-pobj_prep.by']
# 74   ['instal-nsubj', 'install-dobj']
# 75   ['head-pobj_prep.to']
# 76   ['string-dobj']
# 77   ['hit-dobj']
# 78   ['delete-dobj']
# 79   ['access-dobj', 'have-nsubj', 'manage-dobj', 'use-nsubj']
# 80   ['edit-dobj']
# 81   ['configure-dobj']
# 82   ['use-dobj']
# 83   ['access-dobj']
# 84   ['set-pobj_prep.to']
# 85   ['pull-dobj']
# 86   ['work-pobj_prep.with']
# 87   ['export-dobj']
# 88   ['delete-dobj', 'set-pobj_prep.to']
# 89   ['import-dobj']
# 90   ['click-dobj', 'use-nsubj']
# 91   ['choose-dobj']
# 92   ['work-pobj_prep.with']
# 93   ['edit-dobj']
# 94   ['provide-pobj_prep.by']
# 95   ['instal-nsubj', 'install-dobj']
# 96   ['pull-dobj']
# 97   ['string-dobj']
# 98   ['access-dobj']
# 99   ['click-dobj', 'edit-dobj', 'work-pobj_prep.with']
# 100  ['configure-dobj', 'exit-dobj']
# 101  ['delete-dobj']
# 102  ['exit-dobj']
# 103  ['manage-dobj']
# 104  ['exit-dobj', 'head-pobj_prep.to']
# 105  ['edit-dobj', 'open-dobj']
# 106  ['export-dobj', 'import-dobj']
# 107  ['choose-dobj']
# 108  ['pull-dobj']
# 109  ['edit-dobj']
# 110  ['have-nsubj', 'manage-dobj', 'provide-pobj_prep.by', 'run-dobj']
# 111  ['hit-dobj']
# 112  ['generate-dobj']

# %%
noun_df.sort_values(by=['query noun id']).reset_index()
# Out:
#      index  Unnamed: 0      query noun  query noun id  \
# 0    211    211         layer           0
# 1    131    131         editor          1
# 2    395    395         theater         2
# 3    65     65          car             3
# 4    185    185         home            4
# 5    415    415         vehicle         5
# 6    352    352         soil            6
# 7    64     64          candy           7
# 8    410    410         truck           8
# 9    212    212         leak            9
# 10   197    197         internet        10
# 11   314    314         rung            11
# 12   50     50          briefcase       12
# 13   381    381         surface         13
# 14   286    286         pull            14
# 15   354    354         soup            15
# 16   405    405         towel           16
# 17   250    250         nutrition       17
# 18   310    310         route           18
# 19   158    158         formation       19
# 20   18     18          bag             20
# 21   430    430         window          21
# 22   37     37          bluff           22
# 23   32     32          bit             23
# 24   296    296         ref             24
# 25   105    105         crowd           25
# 26   208    208         laundry         26
# 27   277    277         post            27
# 28   273    273         pointer         28
# 29   240    240         model           29
# 30   135    135         engineering     30
# 31   129    129         drop            31
# 32   10     10          arm             32
# 33   124    124         downtown        33
# 34   128    128         driver          34
# 35   189    189         housing         35
# 36   157    157         form            36
# 37   422    422         weapon          37
# 38   361    361         stay            38
# 39   58     58          cab             39
# 40   99     99          control         40
# 41   434    434         wrap            41
# 42   108    108         cycle           42
# 43   409    409         trouser         43
# 44   150    150         finger          44
# 45   366    366         stone           45
# 46   126    126         dressing        46
# 47   36     36          blood           47
# 48   184    184         hobby           48
# 49   200    200         japan           49
# 50   268    268         plain           50
# 51   12     12          art             51
# 52   386    386         system          52
# 53   116    116         director        53
# 54   5      5           alcohol         54
# 55   336    336         short           55
# 56   329    329         sewer           56
# 57   183    183         hip             57
# 58   54     54          bunk            58
# 59   254    254         outfit          59
# 60   280    280         prayer          60
# 61   155    155         floor           61
# 62   16     16          backbone        62
# 63   313    313         rumble          63
# 64   413    413         university      64
# 65   166    166         geneva          65
# 66   433    433         worker          66
# 67   263    263         petal           67
# 68   259    259         patient         68
# 69   206    206         kitchen         69
# 70   432    432         woman           70
# 71   14     14          baby            71
# 72   21     21          bar             72
# 73   167    167         girl            73
# 74   62     62          camp            74
# 75   428    428         whistle         75
# 76   156    156         food            76
# 77   418    418         vintage         77
# 78   23     23          base            78
# 79   383    383         sweetheart      79
# 80   7      7           animal          80
# 81   209    209         laurel          81
# 82   388    388         table           82
# 83   348    348         slope           83
# 84   20     20          balance         84
# 85   427    427         wheelchair      85
# 86   136    136         envelope        86
# 87   425    425         weight          87
# 88   38     38          board           88
# 89   274    274         pole            89
# 90   269    269         plane           90
# 91   130    130         ear             91
# 92   319    319         scientist       92
# 93   293    293         reader          93
# 94   95     95          constraint      94
# 95   195    195         individual      95
# 96   369    369         store           96
# 97   194    194         independent     97
# 98   351    351         soda            98
# 99   421    421         wave            99
# 100  435    435         yard            100
# 101  67     67          case            101
# 102  243    243         movement        102
# 103  165    165         gap             103
# 104  78     78          circle          104
# 105  223    223         manager         105
# 106  338    338         shoulder        106
# 107  362    362         step            107
# 108  76     76          chip            108
# 109  398    398         tie             109
# 110  330    330         shell           110
# 111  221    221         maiden          111
# 112  27     27          bed             112
# 113  251    251         objective       113
# 114  205    205         kiss            114
# 115  347    347         slide           115
# 116  180    180         head            116
# 117  232    232         memory          117
# 118  226    226         match           118
# 119  161    161         framework       119
# 120  344    344         siren           120
# 121  255    255         pack            121
# 122  152    152         fireplace       122
# 123  112    112         defense         123
# 124  256    256         pant            124
# 125  411    411         tube            125
# 126  193    193         imprint         126
# 127  257    257         paper           127
# 128  394    394         terrace         128
# 129  270    270         plant           129
# 130  110    110         date            130
# 131  324    324         seed            131
# 132  368    368         stop            132
# 133  230    230         mechanism       133
# 134  295    295         record          134
# 135  345    345         site            135
# 136  318    318         school          136
# 137  203    203         junction        137
# 138  299    299         representative  138
# 139  333    333         shock           139
# 140  170    170         grip            140
# 141  389    389         tank            141
# 142  190    190         human           142
# 143  238    238         miller          143
# 144  73     73          chest           144
# 145  177    177         hair            145
# 146  353    353         somebody        146
# 147  191    191         humanity        147
# 148  387    387         tab             148
# 149  198    198         intersection    149
# 150  60     60          cabinet         150
# 151  102    102         counter         151
# 152  300    300         reserve         152
# 153  267    267         pillow          153
# 154  215    215         light           154
# 155  79     79          circuit         155
# 156  420    420         wall            156
# 157  340    340         side            157
# 158  55     55          bus             158
# 159  305    305         ride            159
# 160  262    262         personality     160
# 161  309    309         root            161
# 162  414    414         user            162
# 163  294    294         receiver        163
# 164  356    356         speaker         164
# 165  245    245         niche           165
# 166  412    412         turkey          166
# 167  228    228         meal            167
# 168  349    349         slot            168
# 169  323    323         security        169
# 170  11     11          armchair        170
# 171  302    302         restaurant      171
# 172  46     46          bowl            172
# 173  146    146         fig             173
# 174  391    391         target          174
# 175  265    265         physician       175
# 176  121    121         document        176
# 177  311    311         rule            177
# 178  80     80          citizen         178
# 179  147    147         fight           179
# 180  233    233         menu            180
# 181  33     33          black           181
# 182  113    113         desk            182
# 183  396    396         threat          183
# 184  181    181         help            184
# 185  120    120         doctor          185
# 186  45     45          bottom          186
# 187  231    231         medium          187
# 188  220    220         machine         188
# 189  87     87          college         189
# 190  85     85          clothing        190
# 191  137    137         episode         191
# 192  234    234         mess            192
# 193  6      6           ambulance       193
# 194  236    236         microscope      194
# 195  168    168         goal            195
# 196  392    392         taxi            196
# 197  375    375         student         197
# 198  312    312         ruler           198
# 199  118    118         disk            199
# 200  317    317         sauce           200
# 201  341    341         sidewalk        201
# 202  402    402         tom             202
# 203  13     13          automobile      203
# 204  178    178         harbor          204
# 205  272    272         point           205
# 206  22     22          barrier         206
# 207  321    321         screen          207
# 208  359    359         stage           208
# 209  164    164         game            209
# 210  207    207         knob            210
# 211  114    114         diaper          211
# 212  47     47          box             212
# 213  384    384         switch          213
# 214  373    373         strip           214
# 215  141    141         failure         215
# 216  122    122         door            216
# 217  4      4           alarm           217
# 218  40     40          bolt            218
# 219  196    196         institution     219
# 220  117    117         dish            220
# 221  25     25          bathroom        221
# 222  149    149         film            222
# 223  0      0           abode           223
# 224  214    214         level           224
# 225  327    327         set             225
# 226  41     41          bomb            226
# 227  301    301         resistance      227
# 228  287    287         pump            228
# 229  143    143         fence           229
# 230  71     71          chain           230
# 231  358    358         specialist      231
# 232  57     57          button          232
# 233  115    115         diet            233
# 234  59     59          cabin           234
# 235  123    123         doorstep        235
# 236  222    222         mail            236
# 237  400    400         toe             237
# 238  145    145         field           238
# 239  169    169         grade           239
# 240  30     30          bill            240
# 241  24     24          basin           241
# 242  385    385         syringe         242
# 243  138    138         equipment       243
# 244  61     61          call            244
# 245  106    106         cup             245
# 246  49     49          bracket         246
# 247  15     15          back            247
# 248  431    431         wire            248
# 249  199    199         ion             249
# 250  92     92          concrete        250
# 251  337    337         shotgun         251
# 252  283    283         print           252
# 253  8      8           ape             253
# 254  154    154         flood           254
# 255  278    278         pound           255
# 256  69     69          center          256
# 257  307    307         roof            257
# 258  364    364         stilt           258
# 259  148    148         file            259
# 260  31     31          birth           260
# 261  377    377         style           261
# 262  266    266         pig             262
# 263  96     96          construction    263
# 264  172    172         guard           264
# 265  224    224         map             265
# 266  159    159         formula         266
# 267  417    417         villa           267
# 268  316    316         sandwich        268
# 269  393    393         teacher         269
# 270  66     66          card            270
# 271  56     56          bush            271
# 272  179    179         hazard          272
# 273  244    244         network         273
# 274  29     29          bench           274
# 275  88     88          column          275
# 276  82     82          classroom       276
# 277  17     17          background      277
# 278  407    407         train           278
# 279  28     28          bedroom         279
# 280  372    372         street          280
# 281  68     68          cell            281
# 282  382    382         surgery         282
# 283  423    423         web             283
# 284  306    306         roll            284
# 285  289    289         pupil           285
# 286  390    390         tape            286
# 287  429    429         wife            287
# 288  210    210         lawyer          288
# 289  416    416         vein            289
# 290  363    363         stick           290
# 291  70     70          centre          291
# 292  100    100         core            292
# 293  249    249         nut             293
# 294  350    350         snow            294
# 295  275    275         porch           295
# 296  284    284         proportion      296
# 297  119    119         display         297
# 298  52     52          bucket          298
# 299  408    408         triangle        299
# 300  285    285         psychiatrist    300
# 301  53     53          buffer          301
# 302  201    201         java            302
# 303  404    404         top             303
# 304  308    308         room            304
# 305  109    109         dad             305
# 306  374    374         structure       306
# 307  98     98          container       307
# 308  239    239         missile         308
# 309  51     51          buck            309
# 310  151    151         fire            310
# 311  103    103         course          311
# 312  379    379         suitcase        312
# 313  132    132         elder           313
# 314  357    357         spear           314
# 315  227    227         material        315
# 316  304    304         revolver        316
# 317  89     89          communist       317
# 318  2      2           adult           318
# 319  83     83          clock           319
# 320  175    175         guy             320
# 321  406    406         track           321
# 322  218    218         lodging         322
# 323  253    253         outdoors        323
# 324  297    297         refrigerator    324
# 325  401    401         toilet          325
# 326  160    160         foundation      326
# 327  171    171         ground          327
# 328  426    426         western         328
# 329  174    174         gun             329
# 330  399    399         timber          330
# 331  342    342         sieve           331
# 332  343    343         sign            332
# 333  107    107         curtain         333
# 334  63     63          candidate       334
# 335  403    403         tool            335
# 336  43     43          book            336
# 337  81     81          class           337
# 338  281    281         president       338
# 339  163    163         furniture       339
# 340  75     75          china           340
# 341  258    258         parallel        341
# 342  1      1           action          342
# 343  242    242         mouse           343
# 344  35     35          block           344
# 345  346    346         skirt           345
# 346  72     72          chair           346
# 347  48     48          boy             347
# 348  173    173         guest           348
# 349  133    133         employee        349
# 350  90     90          complex         350
# 351  288    288         punch           351
# 352  144    144         fiber           352
# 353  237    237         midwife         353
# 354  111    111         decline         354
# 355  192    192         image           355
# 356  3      3           airport         356
# 357  142    142         family          357
# 358  247    247         notebook        358
# 359  204    204         kid             359
# 360  291    291         race            360
# 361  34     34          blanket         361
# 362  376    376         study           362
# 363  42     42          bond            363
# 364  235    235         microorganism   364
# 365  355    355         source          365
# 366  292    292         range           366
# 367  176    176         habit           367
# 368  162    162         fur             368
# 369  217    217         link            369
# 370  93     93          conjunction     370
# 371  334    334         shoe            371
# 372  322    322         seat            372
# 373  216    216         line            373
# 374  139    139         essence         374
# 375  19     19          bait            375
# 376  424    424         website         376
# 377  9      9           area            377
# 378  371    371         strand          378
# 379  39     39          boat            379
# 380  101    101         cot             380
# 381  97     97          contact         381
# 382  335    335         shop            382
# 383  325    325         sequence        383
# 384  332    332         shift           384
# 385  279    279         power           385
# 386  91     91          computer        386
# 387  153    153         flag            387
# 388  303    303         return          388
# 389  271    271         platform        389
# 390  77     77          church          390
# 391  261    261         people          391
# 392  84     84          clothes         392
# 393  365    365         stock           393
# 394  290    290         push            394
# 395  241    241         monkey          395
# 396  378    378         subject         396
# 397  380    380         support         397
# 398  252    252         office          398
# 399  104    104         courtyard       399
# 400  182    182         hill            400
# 401  229    229         measure         401
# 402  44     44          bottle          402
# 403  86     86          coffee          403
# 404  397    397         threshold       404
# 405  370    370         story           405
# 406  26     26          beauty          406
# 407  225    225         market          407
# 408  134    134         engine          408
# 409  260    260         peak            409
# 410  127    127         drink           410
# 411  140    140         face            411
# 412  328    328         setting         412
# 413  298    298         replacement     413
# 414  188    188         house           414
# 415  264    264         phone           415
# 416  360    360         station         416
# 417  186    186         hospital        417
# 418  331    331         shelter         418
# 419  326    326         server          419
# 420  74     74          child           420
# 421  246    246         node            421
# 422  187    187         host            422
# 423  367    367         stool           423
# 424  339    339         shower          424
# 425  219    219         lunch           425
# 426  320    320         scope           426
# 427  202    202         jean            427
# 428  94     94          connection      428
# 429  125    125         dress           429
# 430  282    282         press           430
# 431  315    315         sand            431
# 432  213    213         leg             432
# 433  248    248         nucleus         433
# 434  276    276         port            434
# 435  419    419         vodka           435
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ground truth extended frames
# 0    ['derive-pobj_prep.from']
# 1    ['appoint-dobj']
# 2    ['attend-dobj', 'go-pobj_prep.to', 'leave-dobj']
# 3    ['afford-dobj', 'approach-dobj', 'bring-dobj', 'buy-dobj', 'carry-pobj_prep.to', 'come-nsubj', 'get-dobj', 'go-nsubj', 'hear-dobj', 'move-dobj', 'pass-dobj', 'put-dobj', 'put-pobj_prep.in', 'repair-dobj', 'return-pobj_prep.to', 'saw-dobj', 'stand-nsubj', 'take-pobj_prep.in', 'wash-dobj']
# 4    ['bring-pobj_prep.into', 'burn-dobj', 'buy-dobj', 'come-pobj_prep.into', 'confine-pobj_prep.to', 'destroy-dobj', 'do-pobj_prep.in', 'go-pobj_prep.into', 'grow-pobj_prep.in', 'have-pobj_prep.in', 'hold-pobj_prep.in', 'meet-pobj_prep.in', 'occupy-dobj', 'place-pobj_prep.in', 'stand-nsubj']
# 5    ['drive-dobj']
# 6    ['rest-pobj_prep.on']
# 7    ['eat-dobj']
# 8    ['drive-dobj']
# 9    ['prevent-dobj']
# 10   ['find-pobj_prep.on']
# 11   ['occupy-dobj']
# 12   ['carry-dobj']
# 13   ['have-pobj_prep.on']
# 14   ['resist-dobj']
# 15   ['drink-dobj']
# 16   ['cover-pobj_prep.with', 'throw-dobj']
# ...
# 423  ['rise-pobj_prep.from']
# 424  ['take-dobj']
# 425  ['bring-dobj', 'prepare-dobj', 'take-pobj_prep.to']
# 426  ['be-pobj_prep.of', 'determine-dobj']
# 427  ['clothe-pobj_prep.in', 'dress-pobj_prep.in', 'wear-dobj']
# 428  ['do-pobj_prep.in', 'draw-dobj']
# 429  ['have-pobj_prep.on']
# 430  ['appear-pobj_prep.in', 'write-pobj_prep.to']
# 431  ['lay-pobj_prep.on']
# 432  ['give-nsubj', 'shake-dobj']
# 433  ['possess-dobj']
# 434  ['seize-dobj']
# 435  ['drink-dobj']

# %%
import numpy as np
from sklearn.metrics import roc_auc_score

y_true = np.array([[0, 0, 0, 1],[1,1,0,1]])
y_pred = np.array([[0.2,0.3,0.2,0.3,], [0.2,0.3,0.2,0.3]])

roc_auc_score(y_true, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-9770a3880a70> in <module>
#       5 y_pred = np.array([[0.2,0.3,0.2,0.3,], [0.2,0.3,0.2,0.3]])
#       6
# ----> 7 roc_auc_score(y_true, y_pred)
#
# /h/19/jadeleiyu/frame_extension/frame_extension_venv/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /h/19/jadeleiyu/frame_extension/frame_extension_venv/lib/python3.6/site-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     396                                              max_fpr=max_fpr),
#     397                                      y_true, y_score, average,
# --> 398                                      sample_weight=sample_weight)
#     399
#     400
#
# /h/19/jadeleiyu/frame_extension/frame_extension_venv/lib/python3.6/site-packages/sklearn/metrics/_base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#     118         y_score_c = y_score.take([c], axis=not_average_axis).ravel()
#     119         score[c] = binary_metric(y_true_c, y_score_c,
# --> 120                                  sample_weight=score_weight)
#     121
#     122     # Average the results
#
# /h/19/jadeleiyu/frame_extension/frame_extension_venv/lib/python3.6/site-packages/sklearn/metrics/_ranking.py in _binary_roc_auc_score(y_true, y_score, sample_weight, max_fpr)
#     221     """Binary roc auc score"""
#     222     if len(np.unique(y_true)) != 2:
# --> 223         raise ValueError("Only one class present in y_true. ROC AUC score "
#     224                          "is not defined in that case.")
#     225
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.

# %%
import pickle
cnp_embeddings_0 = pickle.load(
        open('/h/19/jadeleiyu/frame_extension/data/cnp/cnp_hist_embeddings_{}'.format(1850), 'rb'))

# %%
from numpy import linalg as LA
sum(LA.norm(cnp_embeddings_0, axis=1) <= 1)
# Out:
# 430

# %%
cnp_embeddings_1 = pickle.load(
        open('/h/19/jadeleiyu/frame_extension/data/cnp/cnp_hist_embeddings_{}'.format(2000), 'rb'))

# %%
sum(LA.norm(cnp_embeddings_1, axis=1) > 50)
# Out:
# 107

# %%
cnp_embeddings_0
# Out:
# array([[ 1.53146126, -0.74703433, -0.0237342 , ..., -0.51910192,
#          0.7692309 ,  0.22645915],
#        [ 0.79255469,  0.07837161, -0.20471464, ..., -0.12785049,
#          0.04658372, -0.46108703],
#        [ 1.49134142,  0.45596649, -0.71481728, ...,  0.33234437,
#          0.11171546,  0.55903612],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 3.00398244,  0.38930292, -0.74868414, ..., -0.00562923,
#          0.36869568, -0.31826189],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ]])

# %%
import numpy as np
ling_embeddings_0 = np.load('/h/19/jadeleiyu/frame_extension/data/histwords_embeddings/embeddings_{}.npy'.format(1850))

# %%
sum(LA.norm(ling_embeddings_0, axis=1) > 10.4)
# Out:
# 7

# %%
# Out:
# 4133

# %%
import pandas as pd
list_converter = {'novel nouns': eval, 'most similar novel nouns': eval, 'least similar novel nouns': eval,
                      'established nouns': eval, 'ground truth extended frames': eval,
                      'support nouns': eval, 'ground truth novel nouns': eval, 'support noun counts': eval,
                      'established noun counts': eval}
decade = 1860
decade_noun_test_df = pd.read_csv(
            '/h/19/jadeleiyu/frame_extension/data/gsn/noun_eval_df_{}s.csv'.format(decade),
            converters=list_converter)

# %%
list(decade_noun_test_df['query noun'])
# Out:
# ['accommodation',
#  'acquaintance',
#  'action',
#  'actor',
#  'addict',
#  'adult',
#  'advocate',
#  'aegis',
#  'aggregation',
#  'aide',
#  'aircraft',
#  'airfield',
#  'airplane',
#  'airport',
#  'alarm',
#  'alcohol',
#  'alcoholic',
#  'alien',
#  'ambulance',
#  'ammunition',
#  'ancestor',
#  'animal',
#  'antenna',
#  'apartment',
#  'ape',
#  'appointment',
#  'arc',
#  'architecture',
#  'area',
#  'arena',
#  'arm',
#  'armchair',
#  'array',
#  'arrow',
#  'art',
#  'artifact',
#  'assembly',
#  'assistant',
#  'athletics',
#  'atrium',
#  'attic',
#  'attorney',
#  'aunt',
#  'aura',
#  'author',
#  'authority',
#  'automobile',
#  'baby',
#  'back',
#  'background',
#  'bag',
#  'bait',
#  'balance',
#  'ball',
#  'bank',
#  'bar',
#  'barrel',
#  'barrier',
#  'base',
#  'baseball',
#  'basement',
#  'basin',
#  'basket',
#  'basketball',
#  'bastard',
#  'bath',
#  'bathroom',
#  'batter',
#  'battery',
#  'bay',
#  'beach',
#  'beaker',
#  'beam',
#  'bear',
#  'bearing',
#  'beat',
#  'beauty',
#  'beaver',
#  'bed',
#  'bedroom',
#  'beer',
#  'bell',
#  'belly',
#  'belt',
#  'bench',
#  'berlin',
#  'bicycle',
#  'bill',
#  'bin',
#  'binder',
#  'binding',
#  'bird',
#  'birth',
#  'bit',
#  'bitch',
#  'black',
#  'blade',
#  'blank',
#  'blanket',
#  'blind',
#  'block',
#  'blockade',
#  'blood',
#  'blue',
#  'bluff',
#  'board',
#  'boat',
#  'bobby',
#  'body',
#  'bodyguard',
#  'boiler',
#  'bolt',
#  'bomb',
#  'bond',
#  'bone',
#  'book',
#  'boom',
#  'boot',
#  'booth',
#  'bottle',
#  'bottom',
#  'bowl',
#  'box',
#  'boxer',
#  'boy',
#  'bra',
#  'bracket',
#  'brahman',
#  'brake',
#  'brand',
#  'brandy',
#  'brazil',
#  'breakfast',
#  'brew',
#  'brick',
#  'bridge',
#  'briefcase',
#  'brim',
#  'brush',
#  'buck',
#  'bucket',
#  'buffer',
#  'bug',
#  'building',
#  'bulb',
#  'bull',
#  'bullet',
#  'bunk',
#  'bureau',
#  'burner',
#  'bus',
#  'bush',
#  'button',
#  'cab',
#  'cabin',
#  'cabinet',
#  'cable',
#  'cafe',
#  'calf',
#  'call',
#  'camera',
#  'camp',
#  'can',
#  'candidate',
#  'candle',
#  'candy',
#  'cane',
#  'canvas',
#  'cape',
#  'capsule',
#  'captain',
#  'car',
#  'card',
#  'cardinal',
#  'carrier',
#  'case',
#  'cast',
#  'casualty',
#  'cat',
#  'catheter',
#  'cattle',
#  'ceiling',
#  'cell',
#  'center',
#  'centre',
#  'cereal',
#  'chain',
#  'chair',
#  'chamber',
#  'champagne',
#  'channel',
#  'cheese',
#  'chest',
#  'chicken',
#  'child',
#  'china',
#  'chip',
#  'chocolate',
#  'cinema',
#  'circle',
#  'circuit',
#  'city',
#  'class',
#  'classroom',
#  'climb',
#  'clock',
#  'closer',
#  'cloth',
#  'clothes',
#  'clothing',
#  'club',
#  'clutch',
#  'coast',
#  'coat',
#  'cobweb',
#  'cocktail',
#  'coffee',
#  'coil',
#  'cola',
#  'collection',
#  'college',
#  'column',
#  'commissioner',
#  'communist',
#  'compass',
#  'complex',
#  'compressor',
#  'computer',
#  'concrete',
#  'conductor',
#  'conformation',
#  'connection',
#  'conservatory',
#  'constraint',
#  'construction',
#  'contact',
#  'container',
#  'contractor',
#  'control',
#  'cooling',
#  'cord',
#  'core',
#  'corner',
#  'coronet',
#  'cortex',
#  'cot',
#  'couch',
#  'counselor',
#  'counter',
#  'coupling',
#  'course',
#  'court',
#  'courtroom',
#  'courtyard',
#  'cousin',
#  'cover',
#  'cow',
#  'crack',
#  'crackle',
#  'craft',
#  'craftsman',
#  'cream',
#  'creature',
#  'creep',
#  'crest',
#  'crib',
#  'cross',
#  'crossing',
#  'crossroad',
#  'crowd',
#  'crystal',
#  'cube',
#  'cubicle',
#  'cue',
#  'cup',
#  'cupboard',
#  'curb',
#  'curtain',
#  'cycle',
#  'dad',
#  'daddy',
#  'dairy',
#  'date',
#  'decline',
#  'defence',
#  'defense',
#  'delicacy',
#  'designer',
#  'desk',
#  'dessert',
#  'detector',
#  'device',
#  'dial',
#  'diameter',
#  'diaper',
#  'diaphragm',
#  'diet',
#  'dinner',
#  'director',
#  'dirt',
#  'disc',
#  'dish',
#  'disk',
#  'display',
#  'divan',
#  'dock',
#  'doctor',
#  'document',
#  'dog',
#  'door',
#  'doorstep',
#  'dormitory',
#  'dough',
#  'downtown',
#  'drink',
#  'drive',
#  'driver',
#  'drone',
#  'drop',
#  'drummer',
#  'ear',
#  'earth',
#  'economist',
#  'editor',
#  'egg',
#  'elbow',
#  'elevator',
#  'embryo',
#  'employee',
#  'employer',
#  'engine',
#  'engineering',
#  'envelope',
#  'episode',
#  'equilibrium',
#  'equipment',
#  'essence',
#  'establishment',
#  'extension',
#  'fabric',
#  'facade',
#  'face',
#  'factory',
#  'failure',
#  'falcon',
#  'family',
#  'fare',
#  'farmer',
#  'farmland',
#  'father',
#  'fax',
#  'female',
#  'fence',
#  'fetus',
#  'fiber',
#  'field',
#  'fieldwork',
#  'fig',
#  'fight',
#  'file',
#  'film',
#  'filter',
#  'finger',
#  'fire',
#  'fireplace',
#  'fishing',
#  'flag',
#  'flake',
#  'flash',
#  'flask',
#  'flat',
#  'flicker',
#  'float',
#  'flood',
#  'floor',
#  'flower',
#  'foil',
#  'folder',
#  'font',
#  'food',
#  'fool',
#  'football',
#  'fork',
#  'form',
#  'formation',
#  'formula',
#  'fossa',
#  'foundation',
#  'founder',
#  'foyer',
#  'frame',
#  'framework',
#  'friend',
#  'fruit',
#  'funnel',
#  'furnace',
#  'furrow',
#  'gaff',
#  'game',
#  'gap',
#  'garbage',
#  'gas',
#  'gauge',
#  'gauze',
#  'gear',
#  'gelatin',
#  'generator',
#  'geneva',
#  'girl',
#  'glacier',
#  'glass',
#  'glint',
#  'glory',
#  'goal',
#  'golf',
#  'grade',
#  'grain',
#  'grandfather',
#  'grandma',
#  'grandmother',
#  'grandpa',
#  'grandparent',
#  'grasp',
#  'grass',
#  'grenade',
#  'griffin',
#  'grip',
#  'grocery',
#  'grunt',
#  'guard',
#  'guest',
#  'guide',
#  'guinea',
#  'gun',
#  'guy',
#  'habit',
#  'hair',
#  'hamburger',
#  'hand',
#  'harbor',
#  'hardware',
#  'hat',
#  'hazard',
#  'head',
#  'headquarters',
#  'heart',
#  'hearth',
#  'heel',
#  'help',
#  'hen',
#  'high',
#  'hill',
#  'hip',
#  'hire',
#  'historian',
#  'hobby',
#  'hockey',
#  'hold',
#  'holder',
#  'hole',
#  'home',
#  'homestead',
#  'hood',
#  'hoop',
#  'hospital',
#  'host',
#  'hotel',
#  'house',
#  'housing',
#  'human',
#  'humanity',
#  'hunt',
#  'hurdle',
#  'image',
#  'incubator',
#  'indicator',
#  'individual',
#  'ingredient',
#  'inset',
#  'institution',
#  'instrument',
#  'interface',
#  'internet',
#  'intersection',
#  'ion',
#  'jack',
#  'jacket',
#  'jail',
#  'japan',
#  'java',
#  'jean',
#  'john',
#  'joint',
#  'journalist',
#  'judge',
#  'junction',
#  'justice',
#  'kernel',
#  'key',
#  'keyboard',
#  'khaki',
#  'kid',
#  'killer',
#  'kimono',
#  'kiss',
#  'kit',
#  'kitchen',
#  'knife',
#  'knob',
#  'lady',
#  'lamp',
#  'lattice',
#  'laundry',
#  'lawyer',
#  'layer',
#  'lead',
#  'leak',
#  'ledge',
#  'leg',
#  'lens',
#  'level',
#  'library',
#  'lid',
#  'life',
#  'ligament',
#  'light',
#  'lime',
#  'line',
#  'link',
#  'linkage',
#  'linoleum',
#  'lip',
#  'lipstick',
#  'lobby',
#  'local',
#  'lock',
#  'lodge',
#  'loop',
#  'lotus',
#  'lounge',
#  'lover',
#  'lumber',
#  'lunch',
#  'lure',
#  'lymphocyte',
#  'machete',
#  'machine',
#  'machinery',
#  'magazine',
#  'maiden',
#  'mail',
#  'maker',
#  'makeup',
#  'male',
#  'mammal',
#  'man',
#  'manager',
#  'mantle',
#  'map',
#  'marker',
#  'market',
#  'marrow',
#  'martin',
#  'martini',
#  'mask',
#  'masterpiece',
#  'match',
#  'mate',
#  'material',
#  'matrix',
#  'meal',
#  'measure',
#  'meat',
#  'mechanism',
#  'mediator',
#  'medium',
#  'memory',
#  'menu',
#  'mesh',
#  'mess',
#  'meter',
#  'microorganism',
#  'microscope',
#  'middleman',
#  'milk',
#  'miller',
#  'ministry',
#  'mirror',
#  'missile',
#  'mixture',
#  'model',
#  'module',
#  'mold',
#  'mole',
#  'monastery',
#  'monitor',
#  'monkey',
#  'mosquito',
#  'motor',
#  'mountain',
#  'mouse',
#  'mouth',
#  'movement',
#  'mug',
#  'muzzle',
#  'nail',
#  'national',
#  'native',
#  'nectar',
#  'needle',
#  'network',
#  'newspaper',
#  'niche',
#  'nipple',
#  'node',
#  'notebook',
#  'nucleus',
#  'nurse',
#  'nut',
#  'nutrient',
#  'nutrition',
#  'nylon',
#  'oat',
#  'objective',
#  'observer',
#  'office',
#  'open',
#  'opera',
#  'operator',
#  'organ',
#  'outdoors',
#  'outfit',
#  'outlet',
#  'oven',
#  'overall',
#  'overcoat',
#  'oxford',
#  'pa',
#  'pack',
#  'package',
#  'paint',
#  'pall',
#  'palm',
#  'pan',
#  'pane',
#  'panel',
#  'pant',
#  'paper',
#  'papyrus',
#  'parallel',
#  'park',
#  'partition',
#  'passenger',
#  'patch',
#  'patient',
#  'peak',
#  'pearl',
#  'peasant',
#  'peer',
#  'pen',
#  'pennant',
#  'people',
#  'permit',
#  'person',
#  'personality',
#  'pest',
#  'pet',
#  'phone',
#  'physician',
#  'physicist',
#  'piano',
#  'picnic',
#  'piece',
#  'pigment',
#  'pile',
#  'pillow',
#  'pilot',
#  'pine',
#  'pink',
#  'pistol',
#  'pizza',
#  'place',
#  'plane',
#  'plant',
#  'plaque',
#  'plate',
#  'plateau',
#  'platform',
#  'player',
#  'plaza',
#  'plywood',
#  'podium',
#  'point',
#  'pointer',
#  'pole',
#  'polish',
#  'politician',
#  'poll',
#  'polygon',
#  'pop',
#  'porch',
#  'portfolio',
#  'post',
#  'pot',
#  'potato',
#  'pound',
#  'power',
#  'predator',
#  'president',
#  'press',
#  'primary',
#  'principal',
#  'print',
#  'printer',
#  'prison',
#  'probe',
#  'programmer',
#  'projectile',
#  'proportion',
#  'prospect',
#  'psychiatrist',
#  'pull',
#  'pulp',
#  'pulse',
#  'pump',
#  'punch',
#  'pupil',
#  'purse',
#  'push',
#  'puzzle',
#  'quadrant',
#  'race',
#  'racket',
#  'radio',
#  'radiograph',
#  'radius',
#  'rail',
#  'raise',
#  'ranch',
#  'range',
#  'rat',
#  'ray',
#  'reader',
#  'receiver',
#  'recipient',
#  'record',
#  'reef',
#  'ref',
#  'reformatory',
#  'refrigerator',
#  'regalia',
#  'register',
#  'registrar',
#  'rendering',
#  'replacement',
#  'reporter',
#  'representative',
#  'reserve',
#  'reservoir',
#  'resident',
#  'resistance',
#  'resort',
#  'restaurant',
#  'restraint',
#  'return',
#  'reverse',
#  'revolver',
#  'rice',
#  'ride',
#  'rider',
#  'ridge',
#  'rifle',
#  'rim',
#  'ring',
#  'rise',
#  'road',
#  'rock',
#  'rocker',
#  'roll',
#  'room',
#  'root',
#  'rope',
#  'round',
#  'route',
#  'router',
#  'row',
#  'rubber',
#  'rug',
#  'ruin',
#  'rule',
#  'ruler',
#  'rumble',
#  'rung',
#  'rut',
#  'sack',
#  'sake',
#  'salt',
#  'sandwich',
#  'satellite',
#  'sauce',
#  'sawmill',
#  'scale',
#  'scarf',
#  'school',
#  'scientist',
#  'scope',
#  'screen',
#  'screening',
#  'screw',
#  'seal',
#  'secretary',
#  'security',
#  'seller',
#  'sender',
#  'sequence',
#  'server',
#  'set',
#  'setting',
#  'settler',
#  'shack',
#  'shaft',
#  'sheep',
#  'sheet',
#  'sheeting',
#  'shelf',
#  'shell',
#  'shellfish',
#  'shelter',
#  'shield',
#  'shift',
#  'ship',
#  'shirt',
#  'shock',
#  'shoe',
#  'shop',
#  'short',
#  'shotgun',
#  'shoulder',
#  'shower',
#  'shunt',
#  'sibling',
#  'side',
#  'sidewalk',
#  'sign',
#  'sink',
#  'siren',
#  'sister',
#  'site',
#  'skin',
#  'skirt',
#  'sky',
#  'slide',
#  'slider',
#  'slope',
#  'slot',
#  'smith',
#  'snack',
#  'snow',
#  'snowflake',
#  'sock',
#  'soda',
#  'soil',
#  'somebody',
#  'soul',
#  'source',
#  'span',
#  'speaker',
#  'spear',
#  'specialist',
#  'spiral',
#  'split',
#  'sponge',
#  'spoon',
#  'spore',
#  'sport',
#  'spread',
#  'spring',
#  'stage',
#  'stamp',
#  'stand',
#  'star',
#  'station',
#  'stay',
#  'steel',
#  'step',
#  'stick',
#  'stock',
#  'stone',
#  'stool',
#  'stoop',
#  'stop',
#  'storage',
#  'store',
#  'storey',
#  'stork',
#  'story',
#  'stove',
#  'strand',
#  'stranger',
#  'street',
#  'stretcher',
#  'striker',
#  'string',
#  'strip',
#  'structure',
#  'student',
#  'studio',
#  'study',
#  'stunt',
#  'style',
#  'subject',
#  'submarine',
#  'successor',
#  'sugar',
#  'suitcase',
#  'sun',
#  'sunglass',
#  'support',
#  'supporter',
#  'surface',
#  'surgery',
#  'suspension',
#  'suture',
#  'sweater',
#  'sweet',
#  'sweetheart',
#  'swing',
#  'switch',
#  'symmetry',
#  'syringe',
#  'system',
#  'tab',
#  'table',
#  'tablespoon',
#  'tag',
#  'tank',
#  'tape',
#  'target',
#  'taxi',
#  'teacher',
#  'teddy',
#  'telephone',
#  'telescope',
#  'television',
#  'temple',
#  'theater',
#  'theatre',
#  'thermostat',
#  'third',
#  'thread',
#  'threat',
#  'threshold',
#  'thumb',
#  'tick',
#  'tie',
#  'tile',
#  'toe',
#  'toilet',
#  'token',
#  'tom',
#  'tool',
#  'toothpick',
#  'top',
#  'torpedo',
#  'tourist',
#  'towel',
#  'track',
#  'tractor',
#  'train',
#  'transmission',
#  'transport',
#  'trap',
#  'tray',
#  'tree',
#  'tripod',
#  'trough',
#  'truck',
#  'trump',
#  'tube',
#  'turbine',
#  'turkey',
#  'turnover',
#  'tuxedo',
#  'tv',
#  'typewriter',
#  'umbrella',
#  'underwear',
#  'university',
#  'uplift',
#  'upper',
#  'upstairs',
#  'user',
#  'utensil',
#  'vacuum',
#  'valley',
#  'van',
#  'vegetable',
#  'vehicle',
#  'vein',
#  'veneer',
#  ...]

# %%
1e6
# Out:
# 1000000.0

# %%
import numpy as np
import pickle
import pandas as pd

noun2idx = pickle.load(open('/h/19/jadeleiyu/frame_extension/data/gsn/support_noun2idx.p',
                            'rb'))  # a common noun2idx lookup dict shared across all modalities
noun_decade_counts = pickle.load(open('/h/19/jadeleiyu/frame_extension/data/gsn/noun_decade_counts.p', 'rb'))
list_converter = {'novel nouns': eval, 'most similar novel nouns': eval, 'least similar novel nouns': eval,
                  'established nouns': eval, 'ground truth extended frames': eval,
                  'support nouns': eval, 'ground truth novel nouns': eval, 'support noun counts': eval,
                  'established noun counts': eval}


decade = 1900
decade_idx = int((decade - 1800) / 10)
decade_noun_test_df = pd.read_csv(
        '/h/19/jadeleiyu/frame_extension/data/gsn/noun_eval_df_{}s.csv'.format(decade),
        converters=list_converter)
noun_counts = noun_decade_counts[decade_idx]
noun2decade_count = {n: noun_counts[idx] for (n, idx) in noun2idx.items()}
prediction_dir = '/h/19/jadeleiyu/frame_extension/predictions/'

# %%
precisions_f_ling = pickle.load(open(prediction_dir + 'mean_precisions_exemplar_loss_ling', 'rb'))[int((decade - 1850) / 10)]
precisions_f_vis_ont = pickle.load(open(prediction_dir + 'mean_precisions_exemplar_loss_vis-ont', 'rb'))[int((decade - 1850) / 10)]
precisions_f_vis = pickle.load(open(prediction_dir + 'mean_precisions_exemplar_loss_vis', 'rb'))[int((decade - 1850) / 10)]
precisions_f_vis = pickle.load(open(prediction_dir + 'mean_precisions_exemplar_loss_vis', 'rb'))[int((decade - 1850) / 10)]


query_nouns = list(decade_noun_test_df['query noun'])
query_noun_decade_counts = [noun2decade_count[noun] for noun in query_nouns]
decade_noun_test_df['query noun acc count'] = pd.Series(query_noun_decade_counts)
decade_noun_test_df['query noun precision ling'] = pd.Series(precisions_f_ling)
decade_noun_test_df['query noun precision vis-ont'] = pd.Series(precisions_f_vis_ont)
decade_noun_test_df['query noun precision vis'] = pd.Series(precisions_f_vis)

# %%
count_thresholds = np.array([0, 50, 100, 500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000])
decade_mean_precisions_ling = \
    decade_noun_test_df.groupby(pd.cut(decade_noun_test_df['query noun acc count'], count_thresholds)).mean()[
        'query noun precision ling']

decade_mean_precisions_vis_ont = \
    decade_noun_test_df.groupby(pd.cut(decade_noun_test_df['query noun acc count'], count_thresholds)).mean()[
        'query noun precision vis-ont']

decade_mean_precisions_vis = \
    decade_noun_test_df.groupby(pd.cut(decade_noun_test_df['query noun acc count'], count_thresholds)).mean()[
        'query noun precision vis']


print(decade_mean_precisions_ling)
print(decade_mean_precisions_vis_ont)
print(decade_mean_precisions_vis)
# Out:
# query noun acc count
# (0, 50]              0.648817
# (50, 100]            0.595228
# (100, 500]           0.710807
# (500, 1000]          0.749181
# (1000, 5000]         0.732600
# (5000, 10000]        0.729839
# (10000, 50000]       0.685695
# (50000, 100000]      0.632089
# (100000, 500000]     0.539942
# (500000, 1000000]    0.374457
# Name: query noun precision ling, dtype: float64
# query noun acc count
# (0, 50]              0.860493
# (50, 100]            0.861624
# (100, 500]           0.839598
# (500, 1000]          0.848368
# (1000, 5000]         0.806566
# (5000, 10000]        0.795481
# (10000, 50000]       0.751004
# (50000, 100000]      0.694224
# (100000, 500000]     0.575520
# (500000, 1000000]    0.388466
# Name: query noun precision vis-ont, dtype: float64
# query noun acc count
# (0, 50]              0.764771
# (50, 100]            0.767667
# (100, 500]           0.731618
# (500, 1000]          0.733693
# (1000, 5000]         0.714846
# (5000, 10000]        0.684236
# (10000, 50000]       0.677304
# (50000, 100000]      0.630175
# (100000, 500000]     0.536860
# (500000, 1000000]    0.330314
# Name: query noun precision vis, dtype: float64

# %%
import pandas as pd
list_converter = {'novel nouns': eval, 'most similar novel nouns': eval, 'least similar novel nouns': eval,
                  'established nouns': eval, 'ground truth extended frames': eval,
                  'support nouns': eval, 'ground truth novel nouns': eval, 'support noun counts': eval,
                  'established noun counts': eval}
eval_dfs = []
for decade in range(1850, 2000, 10):
    df = pd.read_csv(
        '/h/19/jadeleiyu/frame_extension/data/gsn/frame_eval_df_{}s.csv'.format(decade),
        converters=list_converter)
    L = len(df['frame'])
    df['decade'] = pd.Series([decade]*L)
    eval_dfs.append(df)

result_df = pd.concat(eval_dfs)

# %%
result_df = result_df.drop(columns=['Unnamed: 0'])
result_df
# Out:
#                       frame  \
# 0              abandon-dobj
# 1    accompany-pobj_prep.by
# 2   acquaint-pobj_prep.with
# 3          act-pobj_prep.as
# 4          add-pobj_prep.to
# ..                      ...
# 52              update-dobj
# 53                 use-dobj
# 54         use-pobj_prep.by
# 55                want-dobj
# 56      work-pobj_prep.with
#
#                                         support nouns  \
# 0   [post, place, city, field, system, friend, cam...
# 1   [friend, officer, wife, son, brother, person, ...
# 2   [subject, art, person, man, people, family, wo...
# 3   [interpreter, guide, mediator, judge, secretar...
# 4   [beauty, stock, church, power, comfort, weight...
# ..                                                ...
# 52  [file, record, table, system, model, base, dis...
# 53  [system, model, material, form, power, tool, f...
# 54  [people, author, child, person, teacher, man, ...
# 55  [child, help, man, drink, power, food, life, p...
# 56  [child, people, hand, patient, student, family...
#
#                                   support noun counts  \
# 0   [1457, 1449, 1194, 795, 694, 560, 533, 485, 44...
# 1   [3310, 1927, 1883, 1871, 1461, 826, 802, 713, ...
# 2   [2767, 1728, 1308, 1171, 1045, 1004, 1004, 810...
# 3   [1838, 1832, 1166, 1130, 938, 625, 585, 547, 4...
# 4   [2203, 2108, 1499, 1127, 1123, 807, 753, 655, ...
# ..                                                ...
# 52     [6939, 3639, 1960, 1660, 1423, 1355, 795, 751]
# 53  [293365, 233637, 175082, 138665, 135267, 11656...
# 54  [37706, 25777, 17002, 14769, 13727, 13219, 130...
# 55  [29723, 27833, 11995, 11432, 9053, 8496, 8425,...
# 56  [73216, 61524, 34329, 28293, 23080, 22396, 171...
#
#                              ground truth novel nouns  decade
# 0   [car, equipment, goal, site, area, weapon, act...    1850
# 1   [adult, envelope, level, failure, decline, wav...    1850
# 2   [personality, worker, background, tool, patien...    1850
# 3   [bridge, middleman, host, filter, link, buffer...    1850
# 4   [diet, pan, medium, sauce, file, pot, model, t...    1850
# ..                                                ...     ...
# 52  [control, setting, form, package, source, inte...    1990
# 53  [equal, python, website, hash, ant, owl, mitt,...    1990
# 54  [filter, connection, studio, switch, tag, web,...    1990
# 55  [setting, rainbow, fry, clip, player, server, ...    1990
# 56  [track, clip, setting, key, node, link, channe...    1990
#
# [8764 rows x 5 columns]

# %%
cols = result_df.columns.tolist()
cols
# Out:
# ['frame',
#  'support nouns',
#  'support noun counts',
#  'ground truth novel nouns',
#  'decade']

# %%
cols = [cols[-1]] + cols[:-1]
cols
# Out:
# ['decade',
#  'frame',
#  'support nouns',
#  'support noun counts',
#  'ground truth novel nouns']

# %%
result_df = result_df[cols]
result_df
# Out:
#     decade                    frame  \
# 0     1850             abandon-dobj
# 1     1850   accompany-pobj_prep.by
# 2     1850  acquaint-pobj_prep.with
# 3     1850         act-pobj_prep.as
# 4     1850         add-pobj_prep.to
# ..     ...                      ...
# 52    1990              update-dobj
# 53    1990                 use-dobj
# 54    1990         use-pobj_prep.by
# 55    1990                want-dobj
# 56    1990      work-pobj_prep.with
#
#                                         support nouns  \
# 0   [post, place, city, field, system, friend, cam...
# 1   [friend, officer, wife, son, brother, person, ...
# 2   [subject, art, person, man, people, family, wo...
# 3   [interpreter, guide, mediator, judge, secretar...
# 4   [beauty, stock, church, power, comfort, weight...
# ..                                                ...
# 52  [file, record, table, system, model, base, dis...
# 53  [system, model, material, form, power, tool, f...
# 54  [people, author, child, person, teacher, man, ...
# 55  [child, help, man, drink, power, food, life, p...
# 56  [child, people, hand, patient, student, family...
#
#                                   support noun counts  \
# 0   [1457, 1449, 1194, 795, 694, 560, 533, 485, 44...
# 1   [3310, 1927, 1883, 1871, 1461, 826, 802, 713, ...
# 2   [2767, 1728, 1308, 1171, 1045, 1004, 1004, 810...
# 3   [1838, 1832, 1166, 1130, 938, 625, 585, 547, 4...
# 4   [2203, 2108, 1499, 1127, 1123, 807, 753, 655, ...
# ..                                                ...
# 52     [6939, 3639, 1960, 1660, 1423, 1355, 795, 751]
# 53  [293365, 233637, 175082, 138665, 135267, 11656...
# 54  [37706, 25777, 17002, 14769, 13727, 13219, 130...
# 55  [29723, 27833, 11995, 11432, 9053, 8496, 8425,...
# 56  [73216, 61524, 34329, 28293, 23080, 22396, 171...
#
#                              ground truth novel nouns
# 0   [car, equipment, goal, site, area, weapon, act...
# 1   [adult, envelope, level, failure, decline, wav...
# 2   [personality, worker, background, tool, patien...
# 3   [bridge, middleman, host, filter, link, buffer...
# 4   [diet, pan, medium, sauce, file, pot, model, t...
# ..                                                ...
# 52  [control, setting, form, package, source, inte...
# 53  [equal, python, website, hash, ant, owl, mitt,...
# 54  [filter, connection, studio, switch, tag, web,...
# 55  [setting, rainbow, fry, clip, player, server, ...
# 56  [track, clip, setting, key, node, link, channe...
#
# [8764 rows x 5 columns]

# %%
result_df.to_csv('/h/19/jadeleiyu/frame_extension/data/gsn/frame_eval_df_all.csv', index=False)
